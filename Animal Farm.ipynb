# %% [markdown]
# # Importing libraries.

# %%
from re import split
import re
import pandas as pd
import plotly as plt
import seaborn as sns
import pandas as pd
import string


import sqlalchemy as alch
from getpass import getpass


from wordcloud import WordCloud, STOPWORDS
import numpy as np
from PIL import Image



import spacy

from IPython.display import Image
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords

from wordcloud import WordCloud
from langdetect import detect
from textblob import TextBlob

# Visualization
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
# %matplotlib inline
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
from nltk import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

import stylecloud

nltk.download('wordnet')
nltk.download('omw-1.4')
import requests

import os
from flask import Flask
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mataf\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\mataf\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# # Loading file.

# %%
f = open('./src/animal farm.txt','r')

# %%
content = f.read()

# %%
content
# Out:
# 'Narrator: This is Manor Farm. This is Mr. Jones the farmer. Mr. Jones was a bad farmer. He didn’t feed the animals. He didn’t milk the cows. He beat them with a stick. Mr. Jones preferred to drink, to drink a lot at the pub. The animals on Manor Farm were very hungry and very angry. One night, when Mr. Jones was at the pub, the animals had a meeting. Napoleon, the black and white boar had a message. Napoleon: Now, comrades. Listen. I have something to tell you. I have a message for you all. Jones the farmer hasn’t given us any food for days. Animals: Yes, we’re hungry! Where’s our food? Give us food! Napoleon: He hasn’t milked the cows for days. Cows: Moo! We need milking! Napoleon: He hasn’t cleaned our barn for days. Animals: Our barn is dirty! Napoleon: And, on top of that, he beats us with his stick. Animals: Yes, with a stick. That hurts! Napoleon: I say enough! Comrades, enough! We must do something. Boxer: What can we do? Jones is the farmer. Jones is the boss. We are just poor animals. Napoleon: Yes, we are just poor animals. Our lives are miserable. That is the truth. But why are our lives so miserable? The answer is Man. Man makes us work. Man takes all our produce. Man is the only creature that takes without giving. Who gives milk? Cows: We do! Napoleon: Who lays eggs? Hens: We do! Napoleon: Who works in the felds? Boxer: We do! Napoleon: And who eats us? Squealer: Man does! escapadetheatre.es Animal Farm EscapadeTheatre Napoleon: Exactly! Man is our enemy. Without Man our produce will be our own. Without Man we animals will be rich. Without Man we animals will be rich, free and equal. Benjamin: But what can we do? Napoleon: What can we do? Work, comrades, work. Night and day, day and night. Benjamin: But we do work now, we work very hard. Napoleon: Yes, but we must work for the Revolution. Animals: The Revolution?! Napoleon: Yes, this is my message to you comrades. Revolution! The revolution must come. I don’t know when, comrades, maybe tomorrow, maybe in a hundred years, but I know that one day the revolution will come. Then we animals will be free. Rich, free and equal. Animals: Rich, free and equal!? Napoleon: Pass this message on. Pass this message on to future generations. Your children and your children’s children must all fght for the revolution! Yes, and remember Man is our enemy. Whatever has two legs is an enemy. Whatever has four legs or wings is a friend. No animal must ever live in a house, or sleep in a bed, or wear clothes, or drink alcohol, or touch money. No animal must ever kill any other animal. All animals are equal. All: All animals are equal. Napoleon: Now, many years ago when I was a little pig, my mother sang me a song. I had forgotten it, but last night, I remembered it. Listen and learn, comrades. (He sings) Beasts of England, Beasts of Ireland, Beasts of land, and sea and skies. Hear the hoof beats of tomorrow, see the golden future rise. Now the day of beasts is coming, tyrant man shall lose his throne, And the shining felds of England shall be ruled by beasts alone. (The animals join in) Beasts of England, Beasts of Ireland, Beasts of land, and sea and skies. Hear the hoof beats of tomorrow, see the golden future rise. Now the day of beasts is coming, tyrant man shall lose his throne, And the shining felds of England shall be ruled by beasts alone. Beasts of England, beasts of Ireland, now! Scene 2: The Revolt Jones: (Singing) Who made the cows and sheep so weak? Who feeds the cats and dogs their meat? Man, powerful man, wonderful man!” escapadetheatre.es Animal Farm EscapadeTheatre Narrator: Just at that moment Mr. Jones came home from the pub. He was very drunk and angry at all the noise the animals were making. Jones: What’s going on here? What’s all this noise on my farm? Be quiet you stupid animals. Shut up! (He bursts into the barn disturbed by all the noise and shoots his shotgun into the air. The animals in their anger and frustration turn on Jones. A slow and building chant of ...

# %%
type(content)
# Out:
# str

# %% [markdown]
# # Splitting names and dialogues.

# %%
sp=re.split('(\w{1,17}:)', content)

# %%
sp
# Out:
# ['',
#  'Narrator:',
#  ' This is Manor Farm. This is Mr. Jones the farmer. Mr. Jones was a bad farmer. He didn’t feed the animals. He didn’t milk the cows. He beat them with a stick. Mr. Jones preferred to drink, to drink a lot at the pub. The animals on Manor Farm were very hungry and very angry. One night, when Mr. Jones was at the pub, the animals had a meeting. Napoleon, the black and white boar had a message. ',
#  'Napoleon:',
#  ' Now, comrades. Listen. I have something to tell you. I have a message for you all. Jones the farmer hasn’t given us any food for days. ',
#  'Animals:',
#  ' Yes, we’re hungry! Where’s our food? Give us food! ',
#  'Napoleon:',
#  ' He hasn’t milked the cows for days. ',
#  'Cows:',
#  ' Moo! We need milking! ',
#  'Napoleon:',
#  ' He hasn’t cleaned our barn for days. ',
#  'Animals:',
#  ' Our barn is dirty! ',
#  'Napoleon:',
#  ' And, on top of that, he beats us with his stick. ',
#  'Animals:',
#  ' Yes, with a stick. That hurts! ',
#  'Napoleon:',
#  ' I say enough! Comrades, enough! We must do something. ',
#  'Boxer:',
#  ' What can we do? Jones is the farmer. Jones is the boss. We are just poor animals. ',
#  'Napoleon:',
#  ' Yes, we are just poor animals. Our lives are miserable. That is the truth. But why are our lives so miserable? The answer is Man. Man makes us work. Man takes all our produce. Man is the only creature that takes without giving. Who gives milk? ',
#  'Cows:',
#  ' We do! ',
#  'Napoleon:',
#  ' Who lays eggs? ',
#  'Hens:',
#  ' We do! ',
#  'Napoleon:',
#  ' Who works in the felds? ',
#  'Boxer:',
#  ' We do! ',
#  'Napoleon:',
#  ' And who eats us? ',
#  'Squealer:',
#  ' Man does! escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Napoleon:',
#  ' Exactly! Man is our enemy. Without Man our produce will be our own. Without Man we animals will be rich. Without Man we animals will be rich, free and equal. ',
#  'Benjamin:',
#  ' But what can we do? ',
#  'Napoleon:',
#  ' What can we do? Work, comrades, work. Night and day, day and night. ',
#  'Benjamin:',
#  ' But we do work now, we work very hard. ',
#  'Napoleon:',
#  ' Yes, but we must work for the Revolution. ',
#  'Animals:',
#  ' The Revolution?! ',
#  'Napoleon:',
#  ' Yes, this is my message to you comrades. Revolution! The revolution must come. I don’t know when, comrades, maybe tomorrow, maybe in a hundred years, but I know that one day the revolution will come. Then we animals will be free. Rich, free and equal. ',
#  'Animals:',
#  ' Rich, free and equal!? ',
#  'Napoleon:',
#  ' Pass this message on. Pass this message on to future generations. Your children and your children’s children must all fght for the revolution! Yes, and remember Man is our enemy. Whatever has two legs is an enemy. Whatever has four legs or wings is a friend. No animal must ever live in a house, or sleep in a bed, or wear clothes, or drink alcohol, or touch money. No animal must ever kill any other animal. All animals are equal. ',
#  'All:',
#  ' All animals are equal. ',
#  'Napoleon:',
#  ' Now, many years ago when I was a little pig, my mother sang me a song. I had forgotten it, but last night, I remembered it. Listen and learn, comrades. (He sings) Beasts of England, Beasts of Ireland, Beasts of land, and sea and skies. Hear the hoof beats of tomorrow, see the golden future rise. Now the day of beasts is coming, tyrant man shall lose his throne, And the shining felds of England shall be ruled by beasts alone. (The animals join in) Beasts of England, Beasts of Ireland, Beasts of land, and sea and skies. Hear the hoof beats of tomorrow, see the golden future rise. Now the day of beasts is coming, tyrant man shall lose his throne, And the shining felds of England shall be ruled by beasts alone. Beasts of England, beasts of Ireland, now! Scene ',
#  '2:',
#  ' The Revolt ',
#  'Jones:',
#  ' (Singing) Who made the cows and sheep so weak? Who feeds the cats and dogs their meat? Man, powerful man, wonderful man!” escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Narrator:',
#  ' Just at that moment Mr. Jones came home from the pub. He was very drunk and angry at all the noise the animals were making. ',
#  'Jones:',
#  ' What’s going on here? What’s all this noise on my farm? Be quiet you stupid animals. Shut up! (He bursts into the barn disturbed by all the noise and shoots his shotgun into the air. The animals in their anger and frustration turn on Jones. A slow and building chant of “Out, out, out…” is heard. They chase him of the farm). ',
#  'Napoleon:',
#  ' Well done, everyone. Long live the revolution! ',
#  'Squealer:',
#  ' Long live the revolution! ',
#  'Animals:',
#  ' Long live the revolution! ',
#  'Benjamin:',
#  ' Ahem. Excuse me. It’s wonderful. I don’t want to ruin the party, but what now? Jones has gone. But what do we do now? ',
#  'Boxer:',
#  ' Yes, what do we do now? ',
#  'Squealer:',
#  ' Listen to comrade Napoleon. He will know what to do. ',
#  'Napoleon:',
#  ' Comrades. We have begun the Revolution! ',
#  'Boxer:',
#  ' Yes, but what about the farm? Without Jones who will run the farm? ',
#  'Napoleon:',
#  ' We will run the farm. Didn’t you hear my message? Weren’t you listening, comrade Boxer? Without Man we can become rich and free. ',
#  'Benjamin:',
#  ' Rich, free and equal is what you said. ',
#  'Napoleon:',
#  ' Of course, rich, free and equal. Jones is gone and now we, the animals, will run Manor Farm. ',
#  'Boxer:',
#  ' We will run Manor Farm? But who will be our leader. We must have a leader. ',
#  'Benjamin:',
#  ' We will all be the leader. ',
#  'Squealer:',
#  ' That’s not possible, comrade, Benjamin. We will argue, we will argue and disagree. We must have one leader. Let’s vote. ',
#  'Boxer:',
#  ' Vote? ',
#  'Napoleon:',
#  ' Yes, good idea, comrade Squealer, if we are free we must learn to vote. ',
#  'Squealer:',
#  ' I propose comrade Napoleon as leader. ',
#  'Benjamin:',
#  ' Why? ',
#  'Squealer:',
#  ' Why not? The Revolution was his idea in the frst place. ',
#  'Boxer:',
#  ' Yes, that’s true. ',
#  'Napoleon:',
#  ' Very well. Do you have a problem with that, comrade Benjamin? ',
#  'Benjamin:',
#  ' (They all look at him.) No, no problem. escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Squealer:',
#  ' All those in favour of Napoleon for leader say “Aye”. ',
#  'Animals:',
#  ' Aye. ',
#  'Squealer:',
#  ' Comrade Benjamin? ',
#  'Benjamin:',
#  ' Aye. ',
#  'Napoleon:',
#  ' Good, then it is decided, by absolute majority. Thank you for voting for me, comrades. I am a practical pig, a pig of few words, so I’ll work hard and say little. (He takes out a prepared speech.) These are my election promises. I promise to listen to everyone. I promise to be fair. I promise to treat everyone equally. I promise to be honest. ',
#  'Squealer:',
#  ' With Comrade Napoleon as our leader we will all run Manor Farm. ',
#  'Animals:',
#  ' We will all run Manor Farm! ',
#  'Napoleon:',
#  ' No! ',
#  'Benjamin:',
#  ' No? ',
#  'Napoleon:',
#  ' Not Manor Farm. From now on Manor Farm will be called Animal Farm. Comrade Squealer, would you mind? (Squealer changes the Manor Farm sign to Animal Farm). ',
#  'Squealer:',
#  ' There, Animal Farm! ',
#  'Animals:',
#  ' Animal Farm! ',
#  'Squealer:',
#  ' Long live Animal Farm! ',
#  'Animals:',
#  ' Long live Animal Farm! ',
#  'Squealer:',
#  ' And long live Napoleon! ',
#  'Animal:',
#  ' Long live Napoleon! ',
#  'Napoleon:',
#  ' Benjamin? ',
#  'Benjamin:',
#  ' Long live Animal Farm … and Napoleon, of course. ',
#  'Napoleon:',
#  ' Good, we all agree. It is very important that we all agree. (Napoleon throws his election promises on the foor. Benjamin picks it up and keeps it.) ',
#  'Boxer:',
#  ' Now what do we do? ',
#  'Napoleon:',
#  ' Now we will go into the house. ',
#  'Benjamin:',
#  ' Into the house? But you said, “No animal must ever live in a house.” ',
#  'Napoleon:',
#  ' No, of course, we won’t live in the house, we must never live in the house, but we must see how Man lives. Then we won’t make the same mistakes. ',
#  'Boxer:',
#  ' I’m a bit scared. You don’t know what will be in there. ',
#  'Squealer:',
#  ' Don’t worry comrade Boxer. Our leader Napoleon is brave. We will be safe with him. And comrade Napoleon is always right. escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Boxer:',
#  ' Yes, comrade Napoleon is always right! ',
#  'Napoleon:',
#  ' Of course, come on everyone. Let’s go in. (He pushes Squealer in before him). After you, comrade Squealer. ',
#  'Narrator:',
#  ' The animals went into the house and saw all the things that Man had stolen from them. Scene ',
#  '3:',
#  ' The Repossession ',
#  'Narrator:',
#  ' They saw the hen’s eggs, boiled and fried. ',
#  'Hens:',
#  ' Look, my eggs! ',
#  'Narrator:',
#  ' They saw the cow’s milk, bottled and ready to drink. ',
#  'Cows:',
#  ' Look, my milk! ',
#  'Narrator:',
#  ' They saw some pork chops ready to cook. ',
#  'Squealer:',
#  ' Look, my brother! ',
#  'Napoleon:',
#  ' This is terrible. No animal must ever live in this house. Agreed? ',
#  'Animals:',
#  ' Agreed! ',
#  'Benjamin:',
#  ' Let’s get out of here Boxer. ',
#  'Boxer:',
#  ' Yes, it’s a horrible place. ',
#  'Napoleon:',
#  ' Yes, everyone out. This place is contaminated with Man’s evil. ',
#  'Squealer:',
#  ' Out, everyone, out. ',
#  'Narrator:',
#  ' The animals left that horrible house. But, Napoleon stayed behind and made friends with Jones’s puppy dogs. ',
#  'Napoleon:',
#  ' Here doggies, doggies. Good boys. Come to daddy. Are you all alone? Don’t worry, I’ll look after you. ',
#  'Narrator:',
#  ' Napoleon took the dogs. He took the dogs and hid them. Nobody noticed and the dogs weren’t seen for a very long time. Scene ',
#  '4:',
#  ' The Rules ',
#  'Squealer:',
#  ' Now comrades, to work. We must learn the animal commandments. Here they ',
#  'are:',
#  ' Napoleon’s commandments. These seven commandments are the basic rules of Animalism. ',
#  'Boxer:',
#  ' Animalism? ',
#  'Squealer:',
#  ' Yes, comrade, Animalism. Napoleon has invented the name for our new system. Our new system based on the new rules. Long live Animalism! ',
#  'Animals:',
#  ' Long live Animalism! escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Squealer:',
#  ' Now, repeat after me. One. Whatever goes on two legs is an enemy. ',
#  'Animals:',
#  ' Two legs enemies. ',
#  'Squealer:',
#  ' Two. Whatever goes on four legs, or has wings, is a friend. ',
#  'Animals:',
#  ' Four legs friends. ',
#  'Squealer:',
#  ' Three. Animals shall never wear clothes. ',
#  'Animals:',
#  ' Never wear clothes. ',
#  'Squealer:',
#  ' Four. Animals shall never sleep in a bed. ',
#  'Animals:',
#  ' Never sleep in beds. ',
#  'Squealer:',
#  ' Five. Animals shall never drink alcohol. ',
#  'Animals:',
#  ' Never drink alcohol. ',
#  'Squealer:',
#  ' Six. Animals shall never kill any other animal. ',
#  'Animals:',
#  ' Never kill animals. ',
#  'Squealer:',
#  ' Seven. All animals are equal. ',
#  'Animals:',
#  ' All animals are equal. ',
#  'Squealer:',
#  ' Very good comrades, excellent work. ',
#  'Napoleon:',
#  ' These are the unalterable laws of Animal Farm. These laws must never be changed or broken. ',
#  'Squealer:',
#  ' And to go with our new commandments we have a new fag, The Hoof and Horn. Let’s sing our anthem while we remember our dead brothers, killed at the hands of our enemy, Man. (They raise the new fag, The Hoof and Horn. They sing the anthem. This time it is sad and mournful). Beasts of England, beasts of Ireland, beasts of land, and sea and skies. Hear the hoof beats of tomorrow, see the golden future rise. Now the day of beasts is coming, tyrant man shall lose his throne, And the shining felds of England shall be ruled by beasts alone. Beasts of England, beasts of Ireland, now! Scene ',
#  '5:',
#  ' To Work ',
#  'Napoleon:',
#  ' Now, comrades, to work! To the hayfeld! Let’s see if we can get the harvest in quick, quicker than Jones did. ',
#  'Boxer:',
#  ' But what about the cows? The cows haven’t been milked. They haven’t been milked for days! ',
#  'Cows:',
#  ' Moo! We haven’t been milked for days! escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Napoleon:',
#  ' Don’t worry comrades. We pigs will milk the cows. Our trotters are better than your hooves. We can milk the cows just like Jones did. ',
#  'Benjamin:',
#  ' Jones used to give us some of the cow’s milk. He put some of that milk in our food. ',
#  'Napoleon:',
#  ' Don’t worry about the milk, comrades. The harvest is more important. Go down to the felds and bring in the harvest. Comrade Boxer will lead the way. I will follow in a few minutes. Forward comrades! Work hard; work hard and we will be free. ',
#  'Boxer:',
#  ' I will work harder! ',
#  'Narrator:',
#  ' So the animals went down to the hayfeld to begin the harvest. The pigs stayed behind to milk the cows. The pigs didn’t work in the felds. The pigs didn’t help with the harvest, at all. Boxer and ',
#  'Benjamin:',
#  ' (Singing) Yesterday, the smell of blood, misery, loss and pain, Today is hot with constant work and we all feel the strain, But tomorrow is our children’s day, And we work so hard for them, so that they may gain. ',
#  'Pigs:',
#  ' Milk, milk, milk those cows, milk those cows, don’t think Milk, milk, milk those cows, milk those cows, then drink ',
#  'Narrator:',
#  ' All through the day the animals worked, they were tired but happy, happier than they thought possible. Boxer worked very hard, harder than everyone. ',
#  'Boxer:',
#  ' I will work harder! Boxer and ',
#  'Benjamin:',
#  ' (Singing) Yesterday, the smell of blood, misery, loss and pain, Today is hot with constant work and we all feel the strain, But tomorrow is our children’s day, And we work so hard for them, so that they may gain. ',
#  'Pigs:',
#  ' Milk, milk, milk those cows, milk those cows, don’t think Milk, milk, milk those cows, milk those cows, then drink All ',
#  'sing:',
#  ' But tomorrow is our children’s day And we work so hard for them, c’mon it looks like rain. ',
#  'Narrator:',
#  ' When the animals went back to the farm in the evening, the milk had disappeared. Every day it disappeared. ',
#  'Boxer:',
#  ' Ooh, I’m so tired and hungry after all that work. Where is the milk? ',
#  'Benjamin:',
#  ' Yes, Squealer, have you pigs drunk the milk? ',
#  'Squealer:',
#  ' Yes, comrades we have drunk the milk. escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Boxer:',
#  ' Why? That’s not fair. We must all have some milk. ',
#  'Squealer:',
#  ' Comrades, you don’t think we pigs drink the milk because we like it? No, we don’t like milk, we don’t like apples. But milk and apples, and this has been proven scientifcally, scientifcally, milk and apples are very good for pigs. We pigs are brain-workers. The survival of the farm depends on us. It is for you that we eat the apples and drink the milk, comrades. Do you know what would happen if we pigs failed? ',
#  'Boxer:',
#  ' What would happen? ',
#  'Squealer:',
#  ' Jones would come back! Surely, comrades, you don’t want Jones to come back, do you? ',
#  'Animals:',
#  ' No, Jones, no! ',
#  'Benjamin:',
#  ' Why not? When Jones was here I worked hard every day. Now he’s gone and everything has changed. But I still work hard every day. ',
#  'Napoleon:',
#  ' What’s the matter? Do you disagree with us, comrade Benjamin? Listen everyone; it seems comrade Benjamin wants Jones to come back. Do you want Jones to come back and beat you with his stick, comrade Benjamin? ',
#  'Benjamin:',
#  ' No, I don’t. ',
#  'Napoleon:',
#  ' Are you sure? ',
#  'Benjamin:',
#  ' I defnitely do not want Jones to come back and beat me with his stick, comrade Napoleon. ',
#  'Napoleon:',
#  ' Good. ',
#  'Boxer:',
#  ' You see Benjamin, comrade Napoleon is always right. The pigs are very clever. ',
#  'Squealer:',
#  ' As Boxer says, we pigs are very clever and therefore, we will teach you to read and write. ',
#  'Benjamin:',
#  ' Read and write? What’s the point? There’s nothing worth reading anyway. ',
#  'Squealer:',
#  ' You must learn to read the commandments. ',
#  'Benjamin:',
#  ' Anyway, how can you pigs read and write? ',
#  'Napoleon:',
#  ' Because we’re clever. We’ve been learning. ',
#  'Benjamin:',
#  ' While we’ve been working in the felds you pigs have been learning to read and write? ',
#  'Squealer:',
#  ' Reading and writing is very hard work, comrade Benjamin, very hard work indeed. Now let’s start with the reading lesson. Boxer, repeat after me. ABCDEFG ',
#  'Boxer:',
#  ' BDBDBDB ',
#  'Squealer:',
#  ' HIJKLMNOP ',
#  'Boxer:',
#  ' CHCHCHPITPITPI ',
#  'Squealer:',
#  ' QRS, TUV, WXY and Z ',
#  'Boxer:',
#  ' MmmmmZ escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Squealer:',
#  ' Oh my goodness! Now try to read the commandments. ',
#  'Napoleon:',
#  ' Oh dear, if they can’t read the commandments, comrade Squealer, you’ll have to simplify it. ',
#  'Squealer:',
#  ' Let me think. I know, like this. Repeat. Four legs good, two legs bad. (The sheep love this and continue to chant it). ',
#  'Narrator:',
#  ' The sheep enjoyed the song. They went on singing for ffteen minutes without stopping. Scene ',
#  '6:',
#  ' The Windmill ',
#  'Squealer:',
#  ' (The cock crows) Wake up, comrades! (The animals wake up and grab their tools as if to start work again.) ',
#  'Napoleon:',
#  ' Today is a great day. Today we will start to build a windmill. ',
#  'Animals:',
#  ' A windmill? ',
#  'Squealer:',
#  ' Yes, our great leader Napoleon has a plan, a plan to make our lives easier. ',
#  'Benjamin:',
#  ' Make our lives easier? That won’t be difcult. ',
#  'Squealer:',
#  ' Gather round, comrades, and listen to comrade Napoleon. ',
#  'Napoleon:',
#  ' Last night I had another dream. ',
#  'Benjamin:',
#  ' I’m not surprised with all the sleeping he does. ',
#  'Squealer:',
#  ' Be quiet, Napoleon is speaking. ',
#  'Napoleon:',
#  ' Comrades, we work hard in the felds, we work hard all day ploughing the felds. ',
#  'Benjamin:',
#  ' Well, we do. ',
#  'Napoleon:',
#  ' Comrades, this farm is old fashioned and antiquated. We have only primitive machinery. We have only ploughs, spades and forks. These old fashioned tools make our work very hard. ',
#  'Boxer:',
#  ' But what can we do? They are all the tools we have. ',
#  'Napoleon:',
#  ' Yes, but think of a machine, one machine operated by the wind, operated by the wind to generate electricity. ',
#  'Boxer:',
#  ' A machine which generates electricity? ',
#  'Napoleon:',
#  ' Yes, a windmill. The windmill would generate electricity. Then electricity would run the plough. The plough would do the work in the felds, instead of you. ',
#  'Boxer:',
#  ' No more ploughing! ',
#  'Napoleon:',
#  ' Yes, just imagine how easy your lives will be. I propose we build a windmill. ',
#  'Boxer:',
#  ' But how can we build a windmill? ',
#  'Napoleon:',
#  ' It won’t be easy, comrade Boxer, it won’t be easy at all. We will have to work hard. escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Boxer:',
#  ' How long will it take? ',
#  'Benjamin:',
#  ' Yes, how long will it take? ',
#  'Napoleon:',
#  ' I calculate it will take a year. ',
#  'Animals:',
#  ' A year! ',
#  'Napoleon:',
#  ' Yes, a year of hard work but after that our lives will be easy. ',
#  'Benjamin:',
#  ' If we waste time building a windmill, we won’t work in the felds and if we don’t work in the felds, we will all starve to death! We won’t have a life! ',
#  'Napoleon:',
#  ' Our lives will be easy and we will only work 3 days a week. ',
#  'Animals:',
#  ' Only work 3 days a week! ',
#  'Squealer:',
#  ' Vote for Napoleon and the 3 day week. ',
#  'Benjamin:',
#  ' It’s much too difcult. ',
#  'Boxer:',
#  ' I will work harder. ',
#  'Benjamin:',
#  ' We will die building a windmill. ',
#  'Napoleon:',
#  ' Perhaps some of us will die, comrade Benjamin, but this sacrifce is for the Revolution. You don’t have the right attitude, comrade Benjamin. Be more like comrade Boxer. Discipline, comrades, discipline, that’s the key. Let’s not argue, comrades, let’s vote. ',
#  'Squealer:',
#  ' All those who vote for the 3 day week say “Aye”. ',
#  'Animals:',
#  ' Aye ',
#  'Squealer:',
#  ' All those who vote for Napoleon’s windmill say “Aye”. ',
#  'Animals:',
#  ' Aye ',
#  'Napoleon:',
#  ' Then it is decided. We will build the windmill. ',
#  'Animals:',
#  ' Hurray for the windmill! ',
#  'Napoleon:',
#  ' Now we mustn’t waste any time. We must start work immediately. Build the windmill!! ',
#  'Narrator:',
#  ' All that year the animals worked hard building the windmill. ',
#  'Boxer:',
#  ' I will work harder! Boxer and ',
#  'Benjamin:',
#  ' (Singing) Build that windmill, build it up, build it up, build it up Hold that stone wall, all day long. Sew that sail, sew it up, sew it up, Lift that sail, up to the top. escapadetheatre.es Animal Farm EscapadeTheatre (The animals stop to rest). ',
#  'Napoleon:',
#  ' (Enters with vicious puppy dogs). We must work harder comrades, and, therefore, we must change a few rules. Comrade Squealer, read the new rules. ',
#  'Squealer:',
#  ' ',
#  'One:',
#  ' All animals will work a 60 hour week and on Sundays too. ',
#  'Benjamin:',
#  ' Work on Sundays!? ',
#  'Squealer:',
#  ' This is voluntary, of course, but any animal who doesn’t work will have his food taken away. ',
#  'Benjamin:',
#  ' Our food!? ',
#  'Boxer:',
#  ' I will work harder! (Singing) Build that windmill, build it up, build it up, Hold that stone wall, up all day long. (The animals stop to rest). ',
#  'Napoleon:',
#  ' Squealer, read the rules! ',
#  'Squealer:',
#  ' ',
#  'Two:',
#  ' From now on there will be no more meetings, no more meetings and no more voting. We pigs will make the decisions and you will take orders. ',
#  'Benjamin:',
#  ' That’s not what we decided! All animals are all equal. ',
#  'Napoleon:',
#  ' Of course, all animals are equal. But what if you animals make the wrong decision? Jones would come back. Do you want Jones to come back, comrades? ',
#  'Animals:',
#  ' No, Jones no! ',
#  'Napoleon:',
#  ' Then no more meetings! ',
#  'Boxer:',
#  ' I will work harder! (Singing) Sew that sail, sew it up, sew it up, Lift that sail, up to the top. (They rest.) ',
#  'Napoleon:',
#  ' The rules, Squealer! ',
#  'Squealer:',
#  ' ',
#  'Three:',
#  ' Animal Farm will begin to do business with Man. ',
#  'Animals:',
#  ' Business with Man!? ',
#  'Squealer:',
#  ' We must buy many things. We will sell the eggs to get money. ',
#  'Animals:',
#  ' Money!? ',
#  'Napoleon:',
#  ' Don’t worry, comrades. We pigs will do the dirty business of doing business with Man. Now get to work comrades escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Boxer:',
#  ' I will work harder! Build that windmill, build it up, build it up, Hold that stone wall, up all day long. ',
#  'Benjamin:',
#  ' (Quietly) This isn’t right, Boxer. Didn’t we agree that we wouldn’t do business with humans? ',
#  'Boxer:',
#  ' I don’t remember. ',
#  'Benjamin:',
#  ' Yes, Boxer, we did. “Don’t touch money. Don’t do business with Man.” Don’t you remember? ',
#  'Squealer:',
#  ' Are you sure it’s not something you dreamt, comrades? ',
#  'Boxer:',
#  ' I don’t know, Benjamin. I’m confused. I believe in the revolution but, it’s true, sometimes things don’t seem to happen the way we planned. But I suppose Napoleon is always right. ',
#  'Napoleon:',
#  ' Come on, there’s no time for idle chit chat. Get working! (Dogs growl) ',
#  'Boxer:',
#  ' I will work harder! Sew that sail, sew it up, sew it up, Lift that sail, up to the top. ',
#  'Napoleon:',
#  ' My windmill is fnished. Long live Animal Farm! (They fnish building the windmill and all stand in awe of it. The pigs shake hands and congratulate themselves. The animals drop down exhausted. The pigs go into the house.) Scene ',
#  '7:',
#  ' The Business ',
#  'Narrator:',
#  ' So, the pigs started doing business with Mr. Pilkington from the farm next door. Pilkington came to the farm often to do business with Napoleon. Napoleon sold him the hen’s eggs and Pilkington gave him money. ',
#  'Pilkington:',
#  ' One, two three, four, fve, another ffty pounds for your very fne eggs. (Napoleon gives him the eggs) It’s a pleasure doing business with you Mr. Napoleon, sir. ',
#  'Napoleon:',
#  ' Maybe next time you could bring me some whisky? ',
#  'Pilkington:',
#  ' Whisky, of course, but I need more eggs, Mr. Napoleon, more eggs. ',
#  'Napoleon:',
#  ' More eggs, eh? ',
#  'Narrator:',
#  ' It was also about this time that the pigs moved into the house. ',
#  'Benjamin:',
#  ' Boxer, wake up! I’ve seen them. ',
#  'Boxer:',
#  ' What? Who have you seen? ',
#  'Benjamin:',
#  ' The pigs, Napoleon and Squealer. They’re living in the house. escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Boxer:',
#  ' Impossible. ',
#  'Benjamin:',
#  ' It’s true. They’re living in the house. I’ve seen them through the window. Look! They’re sitting at the table, eating breakfast and reading the newspaper. ',
#  'Boxer:',
#  ' It can’t be true. ',
#  'Benjamin:',
#  ' It is true and the worst thing is that Napoleon is sleeping in a bed. ',
#  'Boxer:',
#  ' Napoleon is sleeping in a bed? But wasn’t there a commandment that said “Animals shall never sleep in a bed?” ',
#  'Benjamin:',
#  ' Yes, let’s see. (They turn to read the commandment and see that it has been changed). ',
#  'Boxer:',
#  ' What does it say? ',
#  'Benjamin:',
#  ' “Animals shall never sleep in a bed… with sheets.” ',
#  'Squealer:',
#  ' So, comrades, you have heard that we pigs are now sleeping in beds. The commandment says, “Animals shall never sleep in a bed with sheets.” We have removed the sheets and we sleep between blankets. We must rest. You don’t want us to be too tired to think, do you comrades? Then Jones would come back! You don’t want Jones to come back, do you? ',
#  'Animals:',
#  ' No, Jones no! ',
#  'Benjamin:',
#  ' Why not? There’s no diference. With Jones we worked hard and we were hungry. Now we work hard and we are still hungry! ',
#  'Boxer:',
#  ' It’s true we are hungry, very hungry. ',
#  'Animals:',
#  ' We’re hungry! Where’s our food? Give us food! ',
#  'Benjamin:',
#  ' You see, because we’ve been building the windmill we have no food. What is comrade Napoleon going to do about it? ',
#  'Napoleon:',
#  ' (Coming from house with Jones’ gun) More eggs, comrade hens, we need more eggs! ',
#  'Benjamin:',
#  ' More eggs, why? ',
#  'Napoleon:',
#  ' We need to sell more eggs so we can buy more food. ',
#  'Hens:',
#  ' More eggs, no! (Hens sing) ',
#  'Hens:',
#  ' We won’t give you the eggs ',
#  'Squealer:',
#  ' You must do your duty. ',
#  'Hens:',
#  ' We won’t give you the eggs, can’t you see we’re broody. ',
#  'Squealer:',
#  ' We must have the eggs; you must pay your way now. ',
#  'Hens:',
#  ' It’s murder, yes murder to take our eggs away now ',
#  'Napoleon:',
#  ' Consider the economics, we must sell the eggs escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Hens:',
#  ' Consider our unborn chicks; we won’t give you the eggs ',
#  'Napoleon:',
#  ' Our feathered comrades, it appears, have lost all sense of reason And their reactionary acts are just the same as TREASON ! ',
#  'Napoleon:',
#  ' Death to all traitors! (He shoots the hens with his gun. Squealer changes the commandment). Now is there anyone else who wants to protest? Now, back to work! (The pigs exit to the house) I think that went rather well, now let’s have a drink! ',
#  'Boxer:',
#  ' He’s killed the hens, he’s killed the hens. Wasn’t there a commandment that said, “Animals shall never kill any other animal.”? ',
#  'Benjamin:',
#  ' Yes, “Animals shall never kill any other animal… (They turn to read the board)…without cause.” (Boxer starts singing ‘Beasts of England’ very quietly) ',
#  'Boxer:',
#  ' Beasts of England, beasts of Ireland, beasts of land, and sea and skies. Hear the hoof beats of tomorrow, see the golden future rise. Now the day of beasts is coming, tyrant man shall lose his throne, And the shining felds of England shall be ruled by beasts alone. Beasts of England, beasts of Ireland, now! Scene ',
#  '8:',
#  ' The Second Windmill (In the house the pigs talk over the quiet singing of the animals.) ',
#  'Napoleon:',
#  ' Now that the animals have fnished building the windmill, they have nothing to do, they have become lazy. We must keep them under control. We must keep them busy working. ',
#  'Squealer:',
#  ' But now we have the windmill their lives are easy. ',
#  'Napoleon:',
#  ' Exactly. We must keep them busy. Comrade Squealer, take this and put it under the windmill. (He gives him a stick of dynamite). ',
#  'Squealer:',
#  ' But… ',
#  'Napoleon:',
#  ' Do as I say! ',
#  'Squealer:',
#  ' Yes, sir, comrade Napoleon, sir! (He creeps up to the windmill while the animals are sleeping and places a stick of dynamite under it. The windmill blows up). ',
#  'Animals:',
#  ' Oh no, our windmill! What has happened? ',
#  'Squealer:',
#  ' It is Jones. I saw Jones the farmer come into the farm and blow up the windmill! I saw him. Death to Jones the farmer! ',
#  'Animals:',
#  ' Death to Jones! escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Napoleon:',
#  ' This is a disaster, comrades. Our enemy, Man, has won a victory. But we will not let him triumph. Animal Farm will survive. Animalism will rule! We will build another windmill and it will be greater than the frst! ',
#  'Benjamin:',
#  ' Another windmill! We will die! ',
#  'Boxer:',
#  ' I will work harder! ',
#  'Narrator:',
#  ' Years passed. Seasons came and went. The animals worked in the felds. They built a new windmill and the farm became very rich. ',
#  'Boxer:',
#  ' (Singing) Build that windmill, build it up, build it up, Hold that stone wall, up all day long. ',
#  'Pigs:',
#  ' Drink, drink, drink, that booze, drink that booze, you stink Change, change, change, that rule, change that rule, don’t think ',
#  'Boxer:',
#  ' Sew that sail, sew it up, sew it up, Lift that sail, up to the top. ',
#  'Pigs:',
#  ' Count, count, count that cash, count that cash, then eat Wear, wear, wear that hat, wear that hat, so neat. ',
#  'Boxer:',
#  ' Build that windmill, build it up, build it up, Hold that stone wall, up all day long. ',
#  'Boxer:',
#  ' Please inform comrade Napoleon that the windmill is fnished. (He collapses) ',
#  'Benjamin:',
#  ' Boxer, are you alright? ',
#  'Boxer:',
#  ' Yes, yes, I just need to rest. (Benjamin turns seeing Squealer running away) What is it Benjamin? ',
#  'Benjamin:',
#  ' (Reading the commandment) “Animals shall never drink alcohol…to excess.” ',
#  'Boxer:',
#  ' Oh dear, but Napoleon is always right! ',
#  'Benjamin:',
#  ' Why do you say that Boxer? ',
#  'Boxer:',
#  ' Napoleon is our leader. We voted for him. ',
#  'Benjamin:',
#  ' We voted for a fair and honest leader for our revolution. (He gets out the election promises leafet from the frst scene) Listen, this is what Napoleon said when we elected him. “These are my election promises. I promise to listen to everyone. I promise to be fair. I promise to treat everyone equally. I promise to be honest.” He has broken every one of his promises, Boxer. ',
#  'Boxer:',
#  ' Yes, but it was so long ago. Everything is diferent now, everything has changed. ',
#  'Benjamin:',
#  ' However much things change they always stay the same. ',
#  'Boxer:',
#  ' I will work harder. escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Benjamin:',
#  ' We can’t go on like this Boxer. We will die! ',
#  'Boxer:',
#  ' Die? Maybe life would be easier in heaven. ',
#  'Benjamin:',
#  ' Do you really believe in heaven, Boxer? ',
#  'Boxer:',
#  ' Oh yes, animal heaven. Up there, in the clouds, there’s a mountain, Sugar Candy Mountain, where we poor animals go when we die. (He sings). On Sugar Candy Mountain, no working is done, Beside a milky fountain, the beasts lie in the sun On Sugar Candy Mountain, you’ll fnd the chocolate lake, And sugar beyond counting and felds of ginger cake Hallelujah, hallelujah, the sugar candy choir. Hallelujah, hallelujah, so fear no more the knackers’ yard Beyond the fences of this life, there lies a hill And all good creatures go there to eat their fll On Sugar Candy Mountain, no working is done, Besides a milky fountain, the beasts lie in the sun Hallelujah, hallelujah, the sugar candy choir Hallelujah, hallelujah, so fear no more the knackers’ yard Hallelujah, hallelujah, the sugar candy choir Hallelujah, hallelujah, so fear no more the knackers’ yard Hallelujah, hallelujah, the sugar candy choir Scene ',
#  '9:',
#  ' The Resolution ',
#  'Napoleon:',
#  ' Shut up! Be quiet you stupid animals. What’s all this noise on my farm? ',
#  'Squealer:',
#  ' From now on singing is prohibited. The revolution is complete and the only song you can sing is the new hymn, which I have written myself, for our great President Napoleon. ',
#  'Benjamin:',
#  ' President? ',
#  'Napoleon:',
#  ' (Enters in full regalia) Yes, thank you, thank you. I have been voted President. ',
#  'Boxer:',
#  ' Voted by whom? ',
#  'Napoleon:',
#  ' By me, myself and I. An absolute majority. I am President and Animal Farm is now a Republic. Sing the new hymn Squealer. ',
#  'Squealer:',
#  ' (He sings). Napo-Napo-Napoleon-Napo-Napo-Napoleon-Napoleoooon! escapadetheatre.es Animal Farm EscapadeTheatre ',
#  'Benjamin:',
#  ' Why do you say the revolution is complete? Where is the three day week? Where is the food and the riches? Are we all free, rich and equal? Where is our animal revolution? ',
#  'Napoleon:',
#  ' Show them the fgures, Squealer! ',
#  'Squealer:',
#  ' (Taking out the graphs) Yes, we are much better of than with Jones. Look, productivity is up 35%, creativity is up by 22%, longevity is up by 50%, and therefore you are 100% more free, rich and equal!! (During this Napoleon has gone over to the board and changed the commandments) ',
#  'Boxer:',
#  ' It’s not true! For once I protest. You pigs have gone far enough. What about the seven commandments? What about “All animals are equal?” ',
#  'Squealer:',
#  ' There’s only one commandment now. Look. ',
#  'Napoleon:',
#  ' (Reading) “All animals are equal, but some are more equal than others.” ',
#  'Narrator:',
#  ' Just at that moment Pilkington came to congratulate Napoleon on his success. ',
#  'Pilkington:',
#  ' Hello, hello. Mr. Napoleon. Congratulations! You have the most proftable farm in England. What’s your secret? ',
#  'Napoleon:',
#  ' Simple. More proft for fewer people. More power in fewer hands. More control of beast and human. Use every piece of land. ',
#  'Pilkington:',
#  ' Excellent! Dear boy, excellent! Congratulations! Ladies and gentleman, I propose a toast, a toast to Animal Farm. ',
#  'Napoleon:',
#  ' No, not to Animal Farm, a more appropriate name is Manor Farm. (Squealer changes the sign) ',
#  'Pilkington:',
#  ' Excellent! To Manor Farm. ',
#  'All:',
#  ' To Manor Farm! ',
#  'Narrator:',
#  ' The animals looked from pig to man and from man to pig again. But already it was impossible to tell which was which\n']

# %% [markdown]
# # Creating a dictionary to turn into a Dataframe.

# %%
list_name=[]
for i in range(1,len(sp),2):
    dic={}
    dic['name']=sp[i]
    dic['text']=sp[i+1]
    list_name.append(dic)

# %%
df=pd.DataFrame(list_name)

# %%
texts=''
for i in list_name:
    texts+=i['text']

# %%
texts
# Out:
# ' This is Manor Farm. This is Mr. Jones the farmer. Mr. Jones was a bad farmer. He didn’t feed the animals. He didn’t milk the cows. He beat them with a stick. Mr. Jones preferred to drink, to drink a lot at the pub. The animals on Manor Farm were very hungry and very angry. One night, when Mr. Jones was at the pub, the animals had a meeting. Napoleon, the black and white boar had a message.  Now, comrades. Listen. I have something to tell you. I have a message for you all. Jones the farmer hasn’t given us any food for days.  Yes, we’re hungry! Where’s our food? Give us food!  He hasn’t milked the cows for days.  Moo! We need milking!  He hasn’t cleaned our barn for days.  Our barn is dirty!  And, on top of that, he beats us with his stick.  Yes, with a stick. That hurts!  I say enough! Comrades, enough! We must do something.  What can we do? Jones is the farmer. Jones is the boss. We are just poor animals.  Yes, we are just poor animals. Our lives are miserable. That is the truth. But why are our lives so miserable? The answer is Man. Man makes us work. Man takes all our produce. Man is the only creature that takes without giving. Who gives milk?  We do!  Who lays eggs?  We do!  Who works in the felds?  We do!  And who eats us?  Man does! escapadetheatre.es Animal Farm EscapadeTheatre  Exactly! Man is our enemy. Without Man our produce will be our own. Without Man we animals will be rich. Without Man we animals will be rich, free and equal.  But what can we do?  What can we do? Work, comrades, work. Night and day, day and night.  But we do work now, we work very hard.  Yes, but we must work for the Revolution.  The Revolution?!  Yes, this is my message to you comrades. Revolution! The revolution must come. I don’t know when, comrades, maybe tomorrow, maybe in a hundred years, but I know that one day the revolution will come. Then we animals will be free. Rich, free and equal.  Rich, free and equal!?  Pass this message on. Pass this message on to future generations. Your children and your children’s children must all fght for the revolution! Yes, and remember Man is our enemy. Whatever has two legs is an enemy. Whatever has four legs or wings is a friend. No animal must ever live in a house, or sleep in a bed, or wear clothes, or drink alcohol, or touch money. No animal must ever kill any other animal. All animals are equal.  All animals are equal.  Now, many years ago when I was a little pig, my mother sang me a song. I had forgotten it, but last night, I remembered it. Listen and learn, comrades. (He sings) Beasts of England, Beasts of Ireland, Beasts of land, and sea and skies. Hear the hoof beats of tomorrow, see the golden future rise. Now the day of beasts is coming, tyrant man shall lose his throne, And the shining felds of England shall be ruled by beasts alone. (The animals join in) Beasts of England, Beasts of Ireland, Beasts of land, and sea and skies. Hear the hoof beats of tomorrow, see the golden future rise. Now the day of beasts is coming, tyrant man shall lose his throne, And the shining felds of England shall be ruled by beasts alone. Beasts of England, beasts of Ireland, now! Scene  The Revolt  (Singing) Who made the cows and sheep so weak? Who feeds the cats and dogs their meat? Man, powerful man, wonderful man!” escapadetheatre.es Animal Farm EscapadeTheatre  Just at that moment Mr. Jones came home from the pub. He was very drunk and angry at all the noise the animals were making.  What’s going on here? What’s all this noise on my farm? Be quiet you stupid animals. Shut up! (He bursts into the barn disturbed by all the noise and shoots his shotgun into the air. The animals in their anger and frustration turn on Jones. A slow and building chant of “Out, out, out…” is heard. They chase him of the farm).  Well done, everyone. Long live the revolution!  Long live the revolution!  Long live the revolution!  Ahem. Excuse me. It’s wonderful. I don’t want to ruin the party, but what now? Jones has gone. But what d ...

# %%
df
# Out:
#             name                                               text
# 0      Narrator:   This is Manor Farm. This is Mr. Jones the far...
# 1      Napoleon:   Now, comrades. Listen. I have something to te...
# 2       Animals:   Yes, we’re hungry! Where’s our food? Give us ...
# 3      Napoleon:               He hasn’t milked the cows for days.
# 4          Cows:                             Moo! We need milking!
# ..           ...                                                ...
# 337  Pilkington:   Excellent! Dear boy, excellent! Congratulatio...
# 338    Napoleon:   No, not to Animal Farm, a more appropriate na...
# 339  Pilkington:                         Excellent! To Manor Farm.
# 340         All:                                    To Manor Farm!
# 341    Narrator:   The animals looked from pig to man and from m...
#
# [342 rows x 2 columns]

# %%
grouped=df.groupby('name'). sum()

# %% [markdown]
# # Sentiment.

# %%
df_sent['polarity'] = df_sent['text'].apply(lambda x: TextBlob(x).sentiment.polarity)
df_sent['subjectivity'] = df_sent['text'].apply(lambda x: TextBlob(x).sentiment.subjectivity)
# Out:
# C:\Users\mataf\AppData\Local\Temp\ipykernel_8884\2564408500.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sent['polarity'] = df_sent['text'].apply(lambda x: TextBlob(x).sentiment.polarity)
# C:\Users\mataf\AppData\Local\Temp\ipykernel_8884\2564408500.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sent['subjectivity'] = df_sent['text'].apply(lambda x: TextBlob(x).sentiment.subjectivity)

# %%
# wragling data
df_lines = df.groupby('name').count()
df_lines = df_lines.sort_values(by=['text'], ascending=False)
top_character_names = df_lines.index.values

# filtering out non-top characters
df_sent = df[df['name'].isin(top_character_names)]
df_sent = df_sent[['name', 'text']]

# calculating sentiment score
sia = SentimentIntensityAnalyzer()
df_sent.reset_index(inplace=True, drop=True)
df_sent[['neg', 'neu', 'pos', 'compound']] = df_sent['text'].apply(sia.polarity_scores).apply(pd.Series)
df_sent
# Out:
#             name                                               text    neg  \
# 0      Narrator:   This is Manor Farm. This is Mr. Jones the far...  0.091
# 1      Napoleon:   Now, comrades. Listen. I have something to te...  0.000
# 2       Animals:   Yes, we’re hungry! Where’s our food? Give us ...  0.000
# 3      Napoleon:               He hasn’t milked the cows for days.   0.000
# 4          Cows:                             Moo! We need milking!   0.000
# ..           ...                                                ...    ...
# 337  Pilkington:   Excellent! Dear boy, excellent! Congratulatio...  0.000
# 338    Napoleon:   No, not to Animal Farm, a more appropriate na...  0.136
# 339  Pilkington:                         Excellent! To Manor Farm.   0.000
# 340         All:                                    To Manor Farm!   0.000
# 341    Narrator:   The animals looked from pig to man and from m...  0.000
#
#        neu    pos  compound
# 0    0.909  0.000   -0.7960
# 1    1.000  0.000    0.0000
# 2    0.709  0.291    0.5080
# 3    1.000  0.000    0.0000
# 4    1.000  0.000    0.0000
# ..     ...    ...       ...
# 337  0.404  0.596    0.9411
# 338  0.864  0.000   -0.2960
# 339  0.429  0.571    0.6114
# 340  1.000  0.000    0.0000
# 341  1.000  0.000    0.0000
#
# [342 rows x 6 columns]

# %% [markdown]
# # Cleaning and ordering to import from SQL.

# %%
df_sent = df_sent[['name', 'text', 'polarity', 'subjectivity','neg','neu','pos','compound']]

# %%
pd.set_option('display.max_colwidth', None)

# %%
df_sent

# %%
df_sent['text'] = df_sent['text'].str.replace('\n','')

# %%
df_sent['name'] = df_sent['name'].str.replace(':','')

# %%
grouped=df_sent.groupby('name'),df_sent['compound'].sum()

# %%
name_counter=df_sent['name'].value_counts()

# %%
test_name= (df_sent[df_sent.groupby("name")["name"].transform('size') >= 3])

# %%
df_sent=df_sent[df_sent['name'].map(df_sent['name'].value_counts()) > 2]

# %%
df_sent['name'] = df_sent['name'].str.replace('[^\w\s#@/:%.,_-]', '', regex=True, flags=re.UNICODE)
# Out:
# C:\Users\mataf\AppData\Local\Temp\ipykernel_8884\4240373636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sent['name'] = df_sent['name'].str.replace('[^\w\s#@/:%.,_-]', '', regex=True, flags=re.UNICODE)

# %%
df_sent['text'] = df_sent['text'].str.replace('[^\w\s#@/:%.,_-]', '', regex=True, flags=re.UNICODE)
# Out:
# C:\Users\mataf\AppData\Local\Temp\ipykernel_8884\3366777211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sent['text'] = df_sent['text'].str.replace('[^\w\s#@/:%.,_-]', '', regex=True, flags=re.UNICODE)

# %% [markdown]
# # Saving CSV file.

# %%
df_sent.to_csv('Anisql.csv',index=False)

# %% [markdown]
# # Visualization

# %% [markdown]
# ## StyleCloud.

# %%
my_stopwords= {"you've",'will','animals','yes','animal','animal farm','now','windmill', 'himself', 'as', 'also', 'herself', 'in', "she'd", 'else', 'up', 'when', "here's", 'could', "where's", 'no', 'how', "isn't", "he'd", 'about', "hadn't", "he'll", 'does', 'him', 'k', "we're", 'since', 'if', 'such', 'yourselves', "wouldn't", 'further', 'its', 'doing', 'an', 'hence', 'once', "i'd", 'own', 'cannot', 'most', 'any', 'www', 'only', 'from', 'both', "haven't", 'with', 'few', 'and', 'do', 'over', 'into', 'she', 'their', 'is', 'it', 'being', 'other', 'at', "shouldn't", "they've", 'a', 'so', 'our', 'me', "hasn't", 'your', 'not', "i'm", 'been', 'hers', 'there', 'why', 'of', 'themselves', 'because', 'for', "you'll", 'com', "we'll", "there's", 'yourself', 'those', 'otherwise', 'can', "you'd", 'these', 'until', 'whom', 'http', "it's", 'be', "don't", 'ever', "who's", 'against', 'yours', 'very', "aren't", 'have', 'having', 'am', 'theirs', "what's", 'again', "doesn't", "when's", 'her', 'he', "i've", 'are', "couldn't", 'here', 'just', 'would', "she'll", "we'd", 'shall', 'or', "shan't", "i'll", 'where', 'out', "mustn't", 'we', 'like', "didn't", 'myself', 'same', "they'll", 'while', 'ours', 'who', 'between', 'through', 'r', 'under', "how's", 'had', 'off', 'were', 'did', 'ought', 'ourselves', 'they', 'before', 'them', 'below', 'then', 'my', "they'd", 'all', 'too', 'was', "let's", 'than', 'to', "wasn't", "won't", 'therefore', "weren't", 'the', 'you', 'that', 'i', 'during', 'however', "he's", "you're", 'by', 'this', 'get', 'some', "they're", 'on', 'has', "can't", 'above', 'but', 'down', 'his', 'nor', 'should', 'after', 'itself', "she's", 'each', "that's", "we've", "why's", 'what', 'more', 'which'}

# %%
stylecloud.gen_stylecloud(content,
                         icon_name='fas fa-yin-yang',
                          palette='colorbrewer.diverging.Spectral_11', background_color='black',custom_stopwords=my_stopwords,
                          gradient='horizontal',output_name='./Img/Yin.png')

# %%
Image(filename='./Img/Yin.png')

# %%
stylecloud.gen_stylecloud(texts,
                         icon_name='fas fa-piggy-bank',
                          palette='colorbrewer.diverging.Spectral_11', background_color='black',
                          gradient='horizontal',stopwords= True,custom_stopwords=my_stopwords,output_name='./Img/pig.png')
Image(filename='./Img/pig.png')

# %% [markdown]
# ## Sentiment analysis.

# %% [markdown]
# ###  Compound boxplot.

# %%
sns.set(rc={"figure.figsize": (10.,7.)})
box=sns.boxplot(data=df_sent, x='name',y='compound')
box.figure.savefig('Img/box.png', dpi=1000)

# %% [markdown]
# ### Mean possitivity.

# %%
sns.set(rc={"figure.figsize": (8.,7.)})
mean_pos=df_sent.groupby(['name'])['pos'].mean().plot(kind='bar',legend=False, color='black');
mean_pos.figure.savefig('Img/mean_pos.png', dpi=1000)

# %% [markdown]
# ### Sentiment quality.

# %%
sns.set_context("poster")
sns.set(rc={"figure.figsize": (6.,5.)})
sns.set_style("whitegrid")

# %%
sem_q=sns.barplot(data=df_sent,palette='dark');
sem_q.figure.savefig('Img/sem_q.png', dpi=1000)

# %% [markdown]
# ### Correlation test.

# %%
plt.figure(figsize=(10,8))
HEATMAP=sns.heatmap(df_sent.corr(),robust=True,annot=True,cmap="YlGnBu");
HEATMAP.figure.savefig('Img/HEATMAP.png', dpi=1000)

# %% [markdown]
# # SQL

# %%
import sqlalchemy as alch
import os
from dotenv import load_dotenv

load_dotenv()

password = getpass("Insert your password here: ")
# Out:
# Insert your password here: ········

# %%
dbName = "project4"
connectionData = f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(connectionData)

# %%
list(engine.execute("SELECT * FROM anisql"))
# Out:
# [(0, 'Narrator', ' This is Manor Farm. This is Mr. Jones the farmer. Mr. Jones was a bad farmer. He didnt feed the animals. He didnt milk the cows. He beat them with a ... (94 characters truncated) ... e very hungry and very angry. One night, when Mr. Jones was at the pub, the animals had a meeting. Napoleon, the black and white boar had a message. ', 0.091, 0.909, 0.0, -0.796),
#  (1, 'Napoleon', ' Now, comrades. Listen. I have something to tell you. I have a message for you all. Jones the farmer hasnt given us any food for days. ', 0.0, 1.0, 0.0, 0.0),
#  (2, 'Animals', ' Yes, were hungry Wheres our food Give us food ', 0.0, 0.709, 0.291, 0.508),
#  (3, 'Napoleon', ' He hasnt milked the cows for days. ', 0.0, 1.0, 0.0, 0.0),
#  (4, 'Cows', ' Moo We need milking ', 0.0, 1.0, 0.0, 0.0),
#  (5, 'Napoleon', ' He hasnt cleaned our barn for days. ', 0.0, 1.0, 0.0, 0.0),
#  (6, 'Animals', ' Our barn is dirty ', 0.516, 0.484, 0.0, -0.4926),
#  (7, 'Napoleon', ' And, on top of that, he beats us with his stick. ', 0.0, 0.847, 0.153, 0.2023),
#  (8, 'Animals', ' Yes, with a stick. That hurts ', 0.373, 0.33, 0.297, -0.1759),
#  (9, 'Napoleon', ' I say enough Comrades, enough We must do something. ', 0.0, 1.0, 0.0, 0.0),
#  (10, 'Boxer', ' What can we do Jones is the farmer. Jones is the boss. We are just poor animals. ', 0.162, 0.838, 0.0, -0.4767),
#  (11, 'Napoleon', ' Yes, we are just poor animals. Our lives are miserable. That is the truth. But why are our lives so miserable The answer is Man. Man makes us work. Man takes all our produce. Man is the only creature that takes without giving. Who gives milk ', 0.207, 0.729, 0.064, -0.8344),
#  (12, 'Cows', ' We do ', 0.0, 1.0, 0.0, 0.0),
#  (13, 'Napoleon', ' Who lays eggs ', 0.0, 1.0, 0.0, 0.0),
#  (14, 'Hens', ' We do ', 0.0, 1.0, 0.0, 0.0),
#  (15, 'Napoleon', ' Who works in the felds ', 0.0, 1.0, 0.0, 0.0),
#  (16, 'Boxer', ' We do ', 0.0, 1.0, 0.0, 0.0),
#  (17, 'Napoleon', ' And who eats us ', 0.0, 1.0, 0.0, 0.0),
#  (18, 'Squealer', ' Man does escapadetheatre.es Animal Farm EscapadeTheatre ', 0.0, 1.0, 0.0, 0.0),
#  (19, 'Napoleon', ' Exactly Man is our enemy. Without Man our produce will be our own. Without Man we animals will be rich. Without Man we animals will be rich, free and equal. ', 0.087, 0.645, 0.268, 0.807),
#  (20, 'Benjamin', ' But what can we do ', 0.0, 1.0, 0.0, 0.0),
#  (21, 'Napoleon', ' What can we do Work, comrades, work. Night and day, day and night. ', 0.0, 1.0, 0.0, 0.0),
#  (22, 'Benjamin', ' But we do work now, we work very hard. ', 0.203, 0.797, 0.0, -0.2592),
#  (23, 'Napoleon', ' Yes, but we must work for the Revolution. ', 0.0, 0.791, 0.209, 0.2144),
#  (24, 'Animals', ' The Revolution ', 0.0, 1.0, 0.0, 0.0),
#  (25, 'Napoleon', ' Yes, this is my message to you comrades. Revolution The revolution must come. I dont know when, comrades, maybe tomorrow, maybe in a hundred years, but I know that one day the revolution will come. Then we animals will be free. Rich, free and equal. ', 0.0, 0.704, 0.296, 0.9512),
#  (26, 'Animals', ' Rich, free and equal ', 0.0, 0.218, 0.782, 0.8016),
#  (27, 'Napoleon', ' Pass this message on. Pass this message on to future generations. Your children and your childrens children must all fght for the revolution Yes, an ... (133 characters truncated) ...  in a house, or sleep in a bed, or wear clothes, or drink alcohol, or touch money. No animal must ever kill any other animal. All animals are equal. ', 0.178, 0.758, 0.064, -0.8883),
#  (29, 'Napoleon', ' Now, many years ago when I was a little pig, my mother sang me a song. I had forgotten it, but last night, I remembered it. Listen and learn, comrad ... (464 characters truncated) ... , tyrant man shall lose his throne, And the shining felds of England shall be ruled by beasts alone. Beasts of England, beasts of Ireland, now Scene ', 0.094, 0.887, 0.019, -0.8762),
#  (32, 'Narrator', ' Just at that moment Mr. Jones came home from the pub. He was very drunk and angry at all the noise the animals were making. ', 0.214, 0.786, 0.0, -0.7397),
#  (34, 'Napoleon', ' Well done, everyone. Long live the revolution ', 0.0, 0.715, 0.285, 0.3382),
#  (35, 'Squealer', ' Long live the revolution ', 0.0, 1.0, 0.0, 0.0),
#  (36, 'Animals', ' Long live the revolution ', 0.0, 1.0, 0.0, 0.0),
#  (37, 'Benjamin', ' Ahem. Excuse me. Its wonderful. I dont want to ruin the party, but what now Jones has gone. But what do we do now ', 0.088, 0.66, 0.252, 0.3527),
#  (38, 'Boxer', ' Yes, what do we do now ', 0.0, 0.649, 0.351, 0.4019),
#  (39, 'Squealer', ' Listen to comrade Napoleon. He will know what to do. ', 0.0, 1.0, 0.0, 0.0),
#  (40, 'Napoleon', ' Comrades. We have begun the Revolution ', 0.0, 1.0, 0.0, 0.0),
#  (41, 'Boxer', ' Yes, but what about the farm Without Jones who will run the farm ', 0.0, 0.844, 0.156, 0.2982),
#  (42, 'Napoleon', ' We will run the farm. Didnt you hear my message Werent you listening, comrade Boxer Without Man we can become rich and free. ', 0.0, 0.743, 0.257, 0.8053),
#  (43, 'Benjamin', ' Rich, free and equal is what you said. ', 0.0, 0.465, 0.535, 0.7845),
#  (44, 'Napoleon', ' Of course, rich, free and equal. Jones is gone and now we, the animals, will run Manor Farm. ', 0.0, 0.699, 0.301, 0.7845),
#  (45, 'Boxer', ' We will run Manor Farm But who will be our leader. We must have a leader. ', 0.0, 1.0, 0.0, 0.0),
#  (46, 'Benjamin', ' We will all be the leader. ', 0.0, 1.0, 0.0, 0.0),
#  (47, 'Squealer', ' Thats not possible, comrade, Benjamin. We will argue, we will argue and disagree. We must have one leader. Lets vote. ', 0.303, 0.697, 0.0, -0.7506),
#  (48, 'Boxer', ' Vote ', 0.0, 1.0, 0.0, 0.0),
#  (49, 'Napoleon', ' Yes, good idea, comrade Squealer, if we are free we must learn to vote. ', 0.0, 0.553, 0.447, 0.836),
#  (50, 'Squealer', ' I propose comrade Napoleon as leader. ', 0.0, 1.0, 0.0, 0.0),
#  (51, 'Benjamin', ' Why ', 0.0, 1.0, 0.0, 0.0),
#  (52, 'Squealer', ' Why not The Revolution was his idea in the frst place. ', 0.0, 1.0, 0.0, 0.0),
#  (53, 'Boxer', ' Yes, thats true. ', 0.0, 0.154, 0.846, 0.6705),
#  (54, 'Napoleon', ' Very well. Do you have a problem with that, comrade Benjamin ', 0.206, 0.611, 0.183, -0.079),
#  (55, 'Benjamin', ' They all look at him. No, no problem. escapadetheatre.es Animal Farm EscapadeTheatre ', 0.441, 0.559, 0.0, -0.7269),
#  (56, 'Squealer', ' All those in favour of Napoleon for leader say Aye. ', 0.0, 0.756, 0.244, 0.4404),
#  (57, 'Animals', ' Aye. ', 0.0, 1.0, 0.0, 0.0),
#  (58, 'Squealer', ' Comrade Benjamin ', 0.0, 1.0, 0.0, 0.0),
#  (59, 'Benjamin', ' Aye. ', 0.0, 1.0, 0.0, 0.0),
#  (60, 'Napoleon', ' Good, then it is decided, by absolute majority. Thank you for voting for me, comrades. I am a practical pig, a pig of few words, so Ill work hard an ... (45 characters truncated) ...  These are my election promises. I promise to listen to everyone. I promise to be fair. I promise to treat everyone equally. I promise to be honest. ', 0.022, 0.608, 0.37, 0.971),
#  (61, 'Squealer', ' With Comrade Napoleon as our leader we will all run Manor Farm. ', 0.0, 1.0, 0.0, 0.0),
#  (62, 'Animals', ' We will all run Manor Farm ', 0.0, 1.0, 0.0, 0.0),
#  (63, 'Napoleon', ' No ', 1.0, 0.0, 0.0, -0.3595),
#  (64, 'Benjamin', ' No ', 1.0, 0.0, 0.0, -0.296),
#  (65, 'Napoleon', ' Not Manor Farm. From now on Manor Farm will be called Animal Farm. Comrade Squealer, would you mind Squealer changes the Manor Farm sign to Animal Farm. ', 0.0, 1.0, 0.0, 0.0),
#  (66, 'Squealer', ' There, Animal Farm ', 0.0, 1.0, 0.0, 0.0),
#  (67, 'Animals', ' Animal Farm ', 0.0, 1.0, 0.0, 0.0),
#  (68, 'Squealer', ' Long live Animal Farm ', 0.0, 1.0, 0.0, 0.0),
#  (69, 'Animals', ' Long live Animal Farm ', 0.0, 1.0, 0.0, 0.0),
#  (70, 'Squealer', ' And long live Napoleon ', 0.0, 1.0, 0.0, 0.0),
#  (72, 'Napoleon', ' Benjamin ', 0.0, 1.0, 0.0, 0.0),
#  (73, 'Benjamin', ' Long live Animal Farm  and Napoleon, of course. ', 0.0, 1.0, 0.0, 0.0),
#  (74, 'Napoleon', ' Good, we all agree. It is very important that we all agree. Napoleon throws his election promises on the foor. Benjamin picks it up and keeps it. ', 0.0, 0.636, 0.364, 0.8908),
#  (75, 'Boxer', ' Now what do we do ', 0.0, 1.0, 0.0, 0.0),
#  (76, 'Napoleon', ' Now we will go into the house. ', 0.0, 1.0, 0.0, 0.0),
#  (77, 'Benjamin', ' Into the house But you said, No animal must ever live in a house. ', 0.0, 1.0, 0.0, 0.0),
#  (78, 'Napoleon', ' No, of course, we wont live in the house, we must never live in the house, but we must see how Man lives. Then we wont make the same mistakes. ', 0.148, 0.852, 0.0, -0.5927),
#  (79, 'Boxer', ' Im a bit scared. You dont know what will be in there. ', 0.225, 0.775, 0.0, -0.4404),
#  (80, 'Squealer', ' Dont worry comrade Boxer. Our leader Napoleon is brave. We will be safe with him. And comrade Napoleon is always right. escapadetheatre.es Animal Farm EscapadeTheatre ', 0.093, 0.705, 0.202, 0.5267),
#  (81, 'Boxer', ' Yes, comrade Napoleon is always right ', 0.0, 0.626, 0.374, 0.4574),
#  (82, 'Napoleon', ' Of course, come on everyone. Lets go in. He pushes Squealer in before him. After you, comrade Squealer. ', 0.0, 1.0, 0.0, 0.0),
#  (83, 'Narrator', ' The animals went into the house and saw all the things that Man had stolen from them. Scene ', 0.158, 0.842, 0.0, -0.4939),
#  (85, 'Narrator', ' They saw the hens eggs, boiled and fried. ', 0.0, 1.0, 0.0, 0.0),
#  (86, 'Hens', ' Look, my eggs ', 0.0, 1.0, 0.0, 0.0),
#  (87, 'Narrator', ' They saw the cows milk, bottled and ready to drink. ', 0.0, 0.783, 0.217, 0.3612),
#  (88, 'Cows', ' Look, my milk ', 0.0, 1.0, 0.0, 0.0),
#  (89, 'Narrator', ' They saw some pork chops ready to cook. ', 0.0, 0.737, 0.263, 0.3612),
#  (90, 'Squealer', ' Look, my brother ', 0.0, 1.0, 0.0, 0.0),
#  (91, 'Napoleon', ' This is terrible. No animal must ever live in this house. Agreed ', 0.323, 0.549, 0.128, -0.4939),
#  (92, 'Animals', ' Agreed ', 0.0, 0.0, 1.0, 0.3382),
#  (93, 'Benjamin', ' Lets get out of here Boxer. ', 0.0, 1.0, 0.0, 0.0),
#  (94, 'Boxer', ' Yes, its a horrible place. ', 0.427, 0.244, 0.329, -0.2023),
#  (95, 'Napoleon', ' Yes, everyone out. This place is contaminated with Mans evil. ', 0.291, 0.53, 0.179, -0.4019),
#  (96, 'Squealer', ' Out, everyone, out. ', 0.0, 1.0, 0.0, 0.0),
#  (97, 'Narrator', ' The animals left that horrible house. But, Napoleon stayed behind and made friends with Joness puppy dogs. ', 0.105, 0.701, 0.194, 0.4404),
#  (98, 'Napoleon', ' Here doggies, doggies. Good boys. Come to daddy. Are you all alone Dont worry, Ill look after you. ', 0.215, 0.658, 0.127, -0.25),
#  (99, 'Narrator', ' Napoleon took the dogs. He took the dogs and hid them. Nobody noticed and the dogs werent seen for a very long time. Scene ', 0.06, 0.94, 0.0, -0.1027),
#  (101, 'Squealer', ' Now comrades, to work. We must learn the animal commandments. Here they ', 0.0, 1.0, 0.0, 0.0),
#  (103, 'Boxer', ' Animalism ', 0.0, 1.0, 0.0, 0.0),
#  (104, 'Squealer', ' Yes, comrade, Animalism. Napoleon has invented the name for our new system. Our new system based on the new rules. Long live Animalism ', 0.0, 0.88, 0.12, 0.4574),
#  (105, 'Animals', ' Long live Animalism escapadetheatre.es Animal Farm EscapadeTheatre ', 0.0, 1.0, 0.0, 0.0),
#  (106, 'Squealer', ' Now, repeat after me. One. Whatever goes on two legs is an enemy. ', 0.226, 0.774, 0.0, -0.5423),
#  (107, 'Animals', ' Two legs enemies. ', 0.615, 0.385, 0.0, -0.4939),
#  (108, 'Squealer', ' Two. Whatever goes on four legs, or has wings, is a friend. ', 0.0, 0.758, 0.242, 0.4939),
#  (109, 'Animals', ' Four legs friends. ', 0.0, 0.392, 0.608, 0.4767),
#  (110, 'Squealer', ' Three. Animals shall never wear clothes. ', 0.0, 1.0, 0.0, 0.0),
#  (111, 'Animals', ' Never wear clothes. ', 0.0, 1.0, 0.0, 0.0),
#  (112, 'Squealer', ' Four. Animals shall never sleep in a bed. ', 0.0, 1.0, 0.0, 0.0),
#  (113, 'Animals', ' Never sleep in beds. ', 0.0, 1.0, 0.0, 0.0),
#  (114, 'Squealer', ' Five. Animals shall never drink alcohol. ', 0.0, 1.0, 0.0, 0.0),
#  (115, 'Animals', ' Never drink alcohol. ', 0.0, 1.0, 0.0, 0.0),
#  (116, 'Squealer', ' Six. Animals shall never kill any other animal. ', 0.0, 0.652, 0.348, 0.5773),
#  (117, 'Animals', ' Never kill animals. ', 0.0, 0.349, 0.651, 0.5773),
#  (118, 'Squealer', ' Seven. All animals are equal. ', 0.0, 1.0, 0.0, 0.0),
#  (119, 'Animals', ' All animals are equal. ', 0.0, 1.0, 0.0, 0.0),
#  (120, 'Squealer', ' Very good comrades, excellent work. ', 0.0, 0.295, 0.705, 0.7996),
#  (121, 'Napoleon', ' These are the unalterable laws of Animal Farm. These laws must never be changed or broken. ', 0.171, 0.829, 0.0, -0.4767),
#  (122, 'Squealer', ' And to go with our new commandments we have a new fag, The Hoof and Horn. Lets sing our anthem while we remember our dead brothers, killed at the ha ... (287 characters truncated) ... , tyrant man shall lose his throne, And the shining felds of England shall be ruled by beasts alone. Beasts of England, beasts of Ireland, now Scene ', 0.207, 0.793, 0.0, -0.979),
#  (124, 'Napoleon', ' Now, comrades, to work To the hayfeld Lets see if we can get the harvest in quick, quicker than Jones did. ', 0.0, 1.0, 0.0, 0.0),
#  (125, 'Boxer', ' But what about the cows The cows havent been milked. They havent been milked for days ', 0.0, 1.0, 0.0, 0.0),
#  (126, 'Cows', ' Moo We havent been milked for days escapadetheatre.es Animal Farm EscapadeTheatre ', 0.0, 1.0, 0.0, 0.0),
#  (127, 'Napoleon', ' Dont worry comrades. We pigs will milk the cows. Our trotters are better than your hooves. We can milk the cows just like Jones did. ', 0.096, 0.726, 0.178, 0.3612),
#  (128, 'Benjamin', ' Jones used to give us some of the cows milk. He put some of that milk in our food. ', 0.0, 1.0, 0.0, 0.0),
#  (129, 'Napoleon', ' Dont worry about the milk, comrades. The harvest is more important. Go down to the felds and bring in the harvest. Comrade Boxer will lead the way. I will follow in a few minutes. Forward comrades Work hard work hard and we will be free. ', 0.121, 0.769, 0.109, 0.2465),
#  (130, 'Boxer', ' I will work harder ', 0.0, 1.0, 0.0, 0.0),
#  (131, 'Narrator', ' So the animals went down to the hayfeld to begin the harvest. The pigs stayed behind to milk the cows. The pigs didnt work in the felds. The pigs didnt help with the harvest, at all. Boxer and ', 0.0, 0.932, 0.068, 0.4019),
#  (132, 'Benjamin', ' Singing Yesterday, the smell of blood, misery, loss and pain, Today is hot with constant work and we all feel the strain, But tomorrow is our childrens day, And we work so hard for them, so that they may gain. ', 0.198, 0.706, 0.096, -0.2381),
#  (133, 'Pigs', ' Milk, milk, milk those cows, milk those cows, dont think Milk, milk, milk those cows, milk those cows, then drink ', 0.0, 1.0, 0.0, 0.0),
#  (134, 'Narrator', ' All through the day the animals worked, they were tired but happy, happier than they thought possible. Boxer worked very hard, harder than everyone. ', 0.119, 0.595, 0.287, 0.8253),
#  (135, 'Boxer', ' I will work harder Boxer and ', 0.0, 1.0, 0.0, 0.0),
#  (136, 'Benjamin', ' Singing Yesterday, the smell of blood, misery, loss and pain, Today is hot with constant work and we all feel the strain, But tomorrow is our childrens day, And we work so hard for them, so that they may gain. ', 0.198, 0.706, 0.096, -0.2381),
#  (137, 'Pigs', ' Milk, milk, milk those cows, milk those cows, dont think Milk, milk, milk those cows, milk those cows, then drink All ', 0.0, 1.0, 0.0, 0.0),
#  (139, 'Narrator', ' When the animals went back to the farm in the evening, the milk had disappeared. Every day it disappeared. ', 0.183, 0.817, 0.0, -0.4215),
#  (140, 'Boxer', ' Ooh, Im so tired and hungry after all that work. Where is the milk ', 0.223, 0.777, 0.0, -0.5777),
#  (141, 'Benjamin', ' Yes, Squealer, have you pigs drunk the milk ', 0.216, 0.541, 0.243, 0.0772),
#  (142, 'Squealer', ' Yes, comrades we have drunk the milk. escapadetheatre.es Animal Farm EscapadeTheatre ', 0.17, 0.638, 0.191, 0.0772),
#  (143, 'Boxer', ' Why Thats not fair. We must all have some milk. ', 0.179, 0.821, 0.0, -0.2411),
#  (144, 'Squealer', ' Comrades, you dont think we pigs drink the milk because we like it No, we dont like milk, we dont like apples. But milk and apples, and this has bee ... (112 characters truncated) ... rvival of the farm depends on us. It is for you that we eat the apples and drink the milk, comrades. Do you know what would happen if we pigs failed ', 0.07, 0.817, 0.114, 0.4309),
#  (145, 'Boxer', ' What would happen ', 0.0, 1.0, 0.0, 0.0),
#  (146, 'Squealer', ' Jones would come back Surely, comrades, you dont want Jones to come back, do you ', 0.0, 0.743, 0.257, 0.5411),
#  (147, 'Animals', ' No, Jones, no ', 0.824, 0.176, 0.0, -0.5707),
#  (148, 'Benjamin', ' Why not When Jones was here I worked hard every day. Now hes gone and everything has changed. But I still work hard every day. ', 0.118, 0.882, 0.0, -0.2023),
#  (149, 'Napoleon', ' Whats the matter Do you disagree with us, comrade Benjamin Listen everyone it seems comrade Benjamin wants Jones to come back. Do you want Jones to come back and beat you with his stick, comrade Benjamin ', 0.081, 0.856, 0.062, -0.4098),
#  (150, 'Benjamin', ' No, I dont. ', 0.688, 0.312, 0.0, -0.296),
#  (151, 'Napoleon', ' Are you sure ', 0.0, 0.465, 0.535, 0.3182),
#  (152, 'Benjamin', ' I defnitely do not want Jones to come back and beat me with his stick, comrade Napoleon. ', 0.075, 0.925, 0.0, -0.0572),
#  (153, 'Napoleon', ' Good. ', 0.0, 0.0, 1.0, 0.4404),
#  (154, 'Boxer', ' You see Benjamin, comrade Napoleon is always right. The pigs are very clever. ', 0.0, 0.785, 0.215, 0.5095),
#  (155, 'Squealer', ' As Boxer says, we pigs are very clever and therefore, we will teach you to read and write. ', 0.0, 0.838, 0.162, 0.5095),
#  (156, 'Benjamin', ' Read and write Whats the point Theres nothing worth reading anyway. ', 0.168, 0.832, 0.0, -0.2561),
#  (157, 'Squealer', ' You must learn to read the commandments. ', 0.0, 1.0, 0.0, 0.0),
#  (158, 'Benjamin', ' Anyway, how can you pigs read and write ', 0.0, 1.0, 0.0, 0.0),
#  (159, 'Napoleon', ' Because were clever. Weve been learning. ', 0.0, 0.625, 0.375, 0.4588),
#  (160, 'Benjamin', ' While weve been working in the felds you pigs have been learning to read and write ', 0.0, 1.0, 0.0, 0.0),
#  (161, 'Squealer', ' Reading and writing is very hard work, comrade Benjamin, very hard work indeed. Now lets start with the reading lesson. Boxer, repeat after me. ABCDEFG ', 0.128, 0.872, 0.0, -0.3369),
#  (162, 'Boxer', ' BDBDBDB ', 0.0, 1.0, 0.0, 0.0),
#  (163, 'Squealer', ' HIJKLMNOP ', 0.0, 1.0, 0.0, 0.0),
#  (164, 'Boxer', ' CHCHCHPITPITPI ', 0.0, 1.0, 0.0, 0.0),
#  (165, 'Squealer', ' QRS, TUV, WXY and Z ', 0.0, 1.0, 0.0, 0.0),
#  (166, 'Boxer', ' MmmmmZ escapadetheatre.es Animal Farm EscapadeTheatre ', 0.0, 1.0, 0.0, 0.0),
#  (167, 'Squealer', ' Oh my goodness Now try to read the commandments. ', 0.0, 0.708, 0.292, 0.5093),
#  (168, 'Napoleon', ' Oh dear, if they cant read the commandments, comrade Squealer, youll have to simplify it. ', 0.0, 0.843, 0.157, 0.3818),
#  (169, 'Squealer', ' Let me think. I know, like this. Repeat. Four legs good, two legs bad. The sheep love this and continue to chant it. ', 0.113, 0.579, 0.309, 0.7269),
#  (170, 'Narrator', ' The sheep enjoyed the song. They went on singing for ffteen minutes without stopping. Scene ', 0.0, 0.733, 0.267, 0.5781),
#  (172, 'Squealer', ' The cock crows Wake up, comrades The animals wake up and grab their tools as if to start work again. ', 0.091, 0.909, 0.0, -0.2244),
#  (173, 'Napoleon', ' Today is a great day. Today we will start to build a windmill. ', 0.0, 0.709, 0.291, 0.6249),
#  (174, 'Animals', ' A windmill ', 0.0, 1.0, 0.0, 0.0),
#  (175, 'Squealer', ' Yes, our great leader Napoleon has a plan, a plan to make our lives easier. ', 0.0, 0.51, 0.49, 0.8625),
#  (176, 'Benjamin', ' Make our lives easier That wont be difcult. ', 0.0, 0.714, 0.286, 0.4215),
#  (177, 'Squealer', ' Gather round, comrades, and listen to comrade Napoleon. ', 0.0, 1.0, 0.0, 0.0),
#  (178, 'Napoleon', ' Last night I had another dream. ', 0.0, 0.667, 0.333, 0.25),
#  (179, 'Benjamin', ' Im not surprised with all the sleeping he does. ', 0.172, 0.828, 0.0, -0.1695),
#  (180, 'Squealer', ' Be quiet, Napoleon is speaking. ', 0.0, 1.0, 0.0, 0.0),
#  (181, 'Napoleon', ' Comrades, we work hard in the felds, we work hard all day ploughing the felds. ', 0.177, 0.823, 0.0, -0.2023),
#  (182, 'Benjamin', ' Well, we do. ', 0.0, 0.488, 0.512, 0.2732),
#  (183, 'Napoleon', ' Comrades, this farm is old fashioned and antiquated. We have only primitive machinery. We have only ploughs, spades and forks. These old fashioned tools make our work very hard. ', 0.057, 0.943, 0.0, -0.1761),
#  (184, 'Boxer', ' But what can we do They are all the tools we have. ', 0.0, 1.0, 0.0, 0.0),
#  (185, 'Napoleon', ' Yes, but think of a machine, one machine operated by the wind, operated by the wind to generate electricity. ', 0.0, 0.902, 0.098, 0.2144),
#  (186, 'Boxer', ' A machine which generates electricity ', 0.0, 1.0, 0.0, 0.0),
#  (187, 'Napoleon', ' Yes, a windmill. The windmill would generate electricity. Then electricity would run the plough. The plough would do the work in the felds, instead of you. ', 0.0, 0.899, 0.101, 0.4019),
#  (188, 'Boxer', ' No more ploughing ', 0.555, 0.445, 0.0, -0.3595),
#  (189, 'Napoleon', ' Yes, just imagine how easy your lives will be. I propose we build a windmill. ', 0.0, 0.663, 0.337, 0.6808),
#  (190, 'Boxer', ' But how can we build a windmill ', 0.0, 1.0, 0.0, 0.0),
#  (191, 'Napoleon', ' It wont be easy, comrade Boxer, it wont be easy at all. We will have to work hard. escapadetheatre.es Animal Farm EscapadeTheatre ', 0.053, 0.725, 0.221, 0.6597),
#  (192, 'Boxer', ' How long will it take ', 0.0, 1.0, 0.0, 0.0),
#  (193, 'Benjamin', ' Yes, how long will it take ', 0.0, 0.649, 0.351, 0.4019),
#  (194, 'Napoleon', ' I calculate it will take a year. ', 0.0, 1.0, 0.0, 0.0),
#  (195, 'Animals', ' A year ', 0.0, 1.0, 0.0, 0.0),
#  (196, 'Napoleon', ' Yes, a year of hard work but after that our lives will be easy. ', 0.071, 0.592, 0.337, 0.6705),
#  (197, 'Benjamin', ' If we waste time building a windmill, we wont work in the felds and if we dont work in the felds, we will all starve to death We wont have a life ', 0.274, 0.726, 0.0, -0.8802),
#  (198, 'Napoleon', ' Our lives will be easy and we will only work 3 days a week. ', 0.0, 0.791, 0.209, 0.4404),
#  (199, 'Animals', ' Only work 3 days a week ', 0.0, 1.0, 0.0, 0.0),
#  (200, 'Squealer', ' Vote for Napoleon and the 3 day week. ', 0.0, 1.0, 0.0, 0.0),
#  (201, 'Benjamin', ' Its much too difcult. ', 0.0, 1.0, 0.0, 0.0),
#  (202, 'Boxer', ' I will work harder. ', 0.0, 1.0, 0.0, 0.0),
#  (203, 'Benjamin', ' We will die building a windmill. ', 0.494, 0.506, 0.0, -0.5994),
#  (204, 'Napoleon', ' Perhaps some of us will die, comrade Benjamin, but this sacrifce is for the Revolution. You dont have the right attitude, comrade Benjamin. Be more like comrade Boxer. Discipline, comrades, discipline, thats the key. Lets not argue, comrades, lets vote. ', 0.054, 0.81, 0.137, 0.585),
#  (205, 'Squealer', ' All those who vote for the 3 day week say Aye. ', 0.0, 1.0, 0.0, 0.0),
#  (206, 'Animals', ' Aye ', 0.0, 1.0, 0.0, 0.0),
#  (207, 'Squealer', ' All those who vote for Napoleons windmill say Aye. ', 0.0, 1.0, 0.0, 0.0),
#  (208, 'Animals', ' Aye ', 0.0, 1.0, 0.0, 0.0),
#  (209, 'Napoleon', ' Then it is decided. We will build the windmill. ', 0.0, 1.0, 0.0, 0.0),
#  (210, 'Animals', ' Hurray for the windmill ', 0.0, 0.429, 0.571, 0.6114),
#  (211, 'Napoleon', ' Now we mustnt waste any time. We must start work immediately. Build the windmill ', 0.207, 0.793, 0.0, -0.5242),
#  (212, 'Narrator', ' All that year the animals worked hard building the windmill. ', 0.135, 0.865, 0.0, -0.1027),
#  (213, 'Boxer', ' I will work harder Boxer and ', 0.0, 1.0, 0.0, 0.0),
#  (214, 'Benjamin', ' Singing Build that windmill, build it up, build it up, build it up Hold that stone wall, all day long. Sew that sail, sew it up, sew it up, Lift that sail, up to the top. escapadetheatre.es Animal Farm EscapadeTheatre The animals stop to rest. ', 0.047, 0.915, 0.038, -0.1027),
#  (215, 'Napoleon', ' Enters with vicious puppy dogs. We must work harder comrades, and, therefore, we must change a few rules. Comrade Squealer, read the new rules. ', 0.102, 0.898, 0.0, -0.3612),
#  (216, 'Squealer', ' ', 0.0, 0.0, 0.0, 0.0),
#  (218, 'Benjamin', ' Work on Sundays ', 0.0, 1.0, 0.0, 0.0),
#  (219, 'Squealer', ' This is voluntary, of course, but any animal who doesnt work will have his food taken away. ', 0.0, 1.0, 0.0, 0.0),
#  (220, 'Benjamin', ' Our food ', 0.0, 1.0, 0.0, 0.0),
#  (221, 'Boxer', ' I will work harder Singing Build that windmill, build it up, build it up, Hold that stone wall, up all day long. The animals stop to rest. ', 0.091, 0.909, 0.0, -0.3595),
#  (222, 'Napoleon', ' Squealer, read the rules ', 0.0, 1.0, 0.0, 0.0),
#  (223, 'Squealer', ' ', 0.0, 0.0, 0.0, 0.0),
#  (225, 'Benjamin', ' Thats not what we decided All animals are all equal. ', 0.0, 1.0, 0.0, 0.0),
#  (226, 'Napoleon', ' Of course, all animals are equal. But what if you animals make the wrong decision Jones would come back. Do you want Jones to come back, comrades ', 0.146, 0.807, 0.047, -0.6199),
#  (227, 'Animals', ' No, Jones no ', 0.824, 0.176, 0.0, -0.5707),
#  (228, 'Napoleon', ' Then no more meetings ', 0.454, 0.546, 0.0, -0.3595),
#  (229, 'Boxer', ' I will work harder Singing Sew that sail, sew it up, sew it up, Lift that sail, up to the top. They rest. ', 0.0, 0.909, 0.091, 0.2714),
#  (230, 'Napoleon', ' The rules, Squealer ', 0.0, 1.0, 0.0, 0.0),
#  (231, 'Squealer', ' ', 0.0, 0.0, 0.0, 0.0),
#  (233, 'Animals', ' Business with Man ', 0.0, 1.0, 0.0, 0.0),
#  (234, 'Squealer', ' We must buy many things. We will sell the eggs to get money. ', 0.0, 1.0, 0.0, 0.0),
#  (235, 'Animals', ' Money ', 0.0, 1.0, 0.0, 0.0),
#  (236, 'Napoleon', ' Dont worry, comrades. We pigs will do the dirty business of doing business with Man. Now get to work comrades escapadetheatre.es Animal Farm EscapadeTheatre ', 0.209, 0.791, 0.0, -0.7003),
#  (237, 'Boxer', ' I will work harder Build that windmill, build it up, build it up, Hold that stone wall, up all day long. ', 0.0, 1.0, 0.0, 0.0),
#  (238, 'Benjamin', ' Quietly This isnt right, Boxer. Didnt we agree that we wouldnt do business with humans ', 0.0, 0.848, 0.152, 0.3612),
#  (239, 'Boxer', ' I dont remember. ', 0.0, 1.0, 0.0, 0.0),
#  (240, 'Benjamin', ' Yes, Boxer, we did. Dont touch money. Dont do business with Man. Dont you remember ', 0.0, 0.838, 0.162, 0.4019),
#  (241, 'Squealer', ' Are you sure its not something you dreamt, comrades ', 0.0, 0.777, 0.223, 0.3182),
#  (242, 'Boxer', ' I dont know, Benjamin. Im confused. I believe in the revolution but, its true, sometimes things dont seem to happen the way we planned. But I suppose Napoleon is always right. ', 0.053, 0.829, 0.118, 0.4678),
#  (243, 'Napoleon', ' Come on, theres no time for idle chit chat. Get working Dogs growl ', 0.172, 0.828, 0.0, -0.3595),
#  (244, 'Boxer', ' I will work harder Sew that sail, sew it up, sew it up, Lift that sail, up to the top. ', 0.0, 0.896, 0.104, 0.2714),
#  (245, 'Napoleon', ' My windmill is fnished. Long live Animal Farm They fnish building the windmill and all stand in awe of it. The pigs shake hands and congratulate themselves. The animals drop down exhausted. The pigs go into the house. Scene ', 0.147, 0.781, 0.071, -0.3382),
#  (247, 'Narrator', ' So, the pigs started doing business with Mr. Pilkington from the farm next door. Pilkington came to the farm often to do business with Napoleon. Napoleon sold him the hens eggs and Pilkington gave him money. ', 0.0, 1.0, 0.0, 0.0),
#  (248, 'Pilkington', ' One, two three, four, fve, another ffty pounds for your very fne eggs. Napoleon gives him the eggs Its a pleasure doing business with you Mr. Napoleon, sir. ', 0.0, 0.875, 0.125, 0.5719),
#  (249, 'Napoleon', ' Maybe next time you could bring me some whisky ', 0.0, 1.0, 0.0, 0.0),
#  (250, 'Pilkington', ' Whisky, of course, but I need more eggs, Mr. Napoleon, more eggs. ', 0.0, 1.0, 0.0, 0.0),
#  (251, 'Napoleon', ' More eggs, eh ', 0.0, 1.0, 0.0, 0.0),
#  (252, 'Narrator', ' It was also about this time that the pigs moved into the house. ', 0.0, 1.0, 0.0, 0.0),
#  (253, 'Benjamin', ' Boxer, wake up Ive seen them. ', 0.0, 1.0, 0.0, 0.0),
#  (254, 'Boxer', ' What Who have you seen ', 0.0, 1.0, 0.0, 0.0),
#  (255, 'Benjamin', ' The pigs, Napoleon and Squealer. Theyre living in the house. escapadetheatre.es Animal Farm EscapadeTheatre ', 0.0, 1.0, 0.0, 0.0),
#  (256, 'Boxer', ' Impossible. ', 0.0, 1.0, 0.0, 0.0),
#  (257, 'Benjamin', ' Its true. Theyre living in the house. Ive seen them through the window. Look Theyre sitting at the table, eating breakfast and reading the newspaper. ', 0.0, 0.886, 0.114, 0.4753),
#  (258, 'Boxer', ' It cant be true. ', 0.0, 0.517, 0.483, 0.4215),
#  (259, 'Benjamin', ' It is true and the worst thing is that Napoleon is sleeping in a bed. ', 0.217, 0.635, 0.148, -0.3182),
#  (260, 'Boxer', ' Napoleon is sleeping in a bed But wasnt there a commandment that said Animals shall never sleep in a bed ', 0.0, 1.0, 0.0, 0.0),
#  (261, 'Benjamin', ' Yes, lets see. They turn to read the commandment and see that it has been changed. ', 0.0, 0.847, 0.153, 0.4019),
#  (262, 'Boxer', ' What does it say ', 0.0, 1.0, 0.0, 0.0),
#  (263, 'Benjamin', ' Animals shall never sleep in a bed with sheets. ', 0.0, 1.0, 0.0, 0.0),
#  (264, 'Squealer', ' So, comrades, you have heard that we pigs are now sleeping in beds. The commandment says, Animals shall never sleep in a bed with sheets. We have re ... (40 characters truncated) ... ankets. We must rest. You dont want us to be too tired to think, do you comrades Then Jones would come back You dont want Jones to come back, do you ', 0.053, 0.908, 0.039, -0.4501),
#  (265, 'Animals', ' No, Jones no ', 0.824, 0.176, 0.0, -0.5707),
#  (266, 'Benjamin', ' Why not Theres no diference. With Jones we worked hard and we were hungry. Now we work hard and we are still hungry ', 0.124, 0.801, 0.076, 0.0976),
#  (267, 'Boxer', ' Its true we are hungry, very hungry. ', 0.0, 0.682, 0.318, 0.4215),
#  (268, 'Animals', ' Were hungry Wheres our food Give us food ', 0.0, 1.0, 0.0, 0.0),
#  (269, 'Benjamin', ' You see, because weve been building the windmill we have no food. What is comrade Napoleon going to do about it ', 0.099, 0.901, 0.0, -0.296),
#  (270, 'Napoleon', ' Coming from house with Jones gun More eggs, comrade hens, we need more eggs ', 0.0, 1.0, 0.0, 0.0),
#  (271, 'Benjamin', ' More eggs, why ', 0.0, 1.0, 0.0, 0.0),
#  (272, 'Napoleon', ' We need to sell more eggs so we can buy more food. ', 0.0, 1.0, 0.0, 0.0),
#  (273, 'Hens', ' More eggs, no Hens sing ', 0.409, 0.591, 0.0, -0.4157),
#  (274, 'Hens', ' We wont give you the eggs ', 0.0, 1.0, 0.0, 0.0),
#  (275, 'Squealer', ' You must do your duty. ', 0.0, 1.0, 0.0, 0.0),
#  (276, 'Hens', ' We wont give you the eggs, cant you see were broody. ', 0.0, 1.0, 0.0, 0.0),
#  (277, 'Squealer', ' We must have the eggs you must pay your way now. ', 0.123, 0.877, 0.0, -0.1027),
#  (278, 'Hens', ' Its murder, yes murder to take our eggs away now ', 0.492, 0.366, 0.141, -0.8271),
#  (279, 'Napoleon', ' Consider the economics, we must sell the eggs escapadetheatre.es Animal Farm EscapadeTheatre ', 0.0, 1.0, 0.0, 0.0),
#  (280, 'Hens', ' Consider our unborn chicks we wont give you the eggs ', 0.0, 1.0, 0.0, 0.0),
#  (281, 'Napoleon', ' Our feathered comrades, it appears, have lost all sense of reason And their reactionary acts are just the same as TREASON  ', 0.247, 0.753, 0.0, -0.7371),
#  (282, 'Napoleon', ' Death to all traitors He shoots the hens with his gun. Squealer changes the commandment. Now is there anyone else who wants to protest Now, back to work The pigs exit to the house I think that went rather well, now lets have a drink ', 0.183, 0.776, 0.042, -0.795),
#  (283, 'Boxer', ' Hes killed the hens, hes killed the hens. Wasnt there a commandment that said, Animals shall never kill any other animal. ', 0.303, 0.572, 0.126, -0.7401),
#  (284, 'Benjamin', ' Yes, Animals shall never kill any other animal They turn to read the boardwithout cause. Boxer starts singing Beasts of England very quietly ', 0.0, 0.765, 0.235, 0.7534),
#  (285, 'Boxer', ' Beasts of England, beasts of Ireland, beasts of land, and sea and skies. Hear the hoof beats of tomorrow, see the golden future rise. Now the day of ... (17 characters truncated) ... , tyrant man shall lose his throne, And the shining felds of England shall be ruled by beasts alone. Beasts of England, beasts of Ireland, now Scene ', 0.083, 0.917, 0.0, -0.6114),
#  (287, 'Napoleon', ' Now that the animals have fnished building the windmill, they have nothing to do, they have become lazy. We must keep them under control. We must keep them busy working. ', 0.079, 0.921, 0.0, -0.3612),
#  (288, 'Squealer', ' But now we have the windmill their lives are easy. ', 0.0, 0.7, 0.3, 0.5927),
#  (289, 'Napoleon', ' Exactly. We must keep them busy. Comrade Squealer, take this and put it under the windmill. He gives him a stick of dynamite. ', 0.0, 1.0, 0.0, 0.0),
#  (290, 'Squealer', ' But ', 0.0, 1.0, 0.0, 0.0),
#  (291, 'Napoleon', ' Do as I say ', 0.0, 1.0, 0.0, 0.0),
#  (292, 'Squealer', ' Yes, sir, comrade Napoleon, sir He creeps up to the windmill while the animals are sleeping and places a stick of dynamite under it. The windmill blows up. ', 0.0, 0.842, 0.158, 0.5707),
#  (293, 'Animals', ' Oh no, our windmill What has happened ', 0.293, 0.707, 0.0, -0.3595),
#  (294, 'Squealer', ' It is Jones. I saw Jones the farmer come into the farm and blow up the windmill I saw him. Death to Jones the farmer ', 0.169, 0.831, 0.0, -0.6688),
#  (295, 'Animals', ' Death to Jones escapadetheatre.es Animal Farm EscapadeTheatre ', 0.411, 0.589, 0.0, -0.636),
#  (296, 'Napoleon', ' This is a disaster, comrades. Our enemy, Man, has won a victory. But we will not let him triumph. Animal Farm will survive. Animalism will rule We will build another windmill and it will be greater than the frst ', 0.188, 0.691, 0.121, -0.4793),
#  (297, 'Benjamin', ' Another windmill We will die ', 0.529, 0.471, 0.0, -0.6688),
#  (298, 'Boxer', ' I will work harder ', 0.0, 1.0, 0.0, 0.0),
#  (299, 'Narrator', ' Years passed. Seasons came and went. The animals worked in the felds. They built a new windmill and the farm became very rich. ', 0.0, 0.844, 0.156, 0.5984),
#  (300, 'Boxer', ' Singing Build that windmill, build it up, build it up, Hold that stone wall, up all day long. ', 0.0, 1.0, 0.0, 0.0),
#  (301, 'Pigs', ' Drink, drink, drink, that booze, drink that booze, you stink Change, change, change, that rule, change that rule, dont think ', 0.124, 0.876, 0.0, -0.4019),
#  (302, 'Boxer', ' Sew that sail, sew it up, sew it up, Lift that sail, up to the top. ', 0.0, 0.893, 0.107, 0.2023),
#  (303, 'Pigs', ' Count, count, count that cash, count that cash, then eat Wear, wear, wear that hat, wear that hat, so neat. ', 0.0, 0.831, 0.169, 0.5949),
#  (304, 'Boxer', ' Build that windmill, build it up, build it up, Hold that stone wall, up all day long. ', 0.0, 1.0, 0.0, 0.0),
#  (305, 'Boxer', ' Please inform comrade Napoleon that the windmill is fnished. He collapses ', 0.0, 0.813, 0.187, 0.3182),
#  (306, 'Benjamin', ' Boxer, are you alright ', 0.0, 0.6, 0.4, 0.25),
#  (307, 'Boxer', ' Yes, yes, I just need to rest. Benjamin turns seeing Squealer running away What is it Benjamin ', 0.0, 0.722, 0.278, 0.6597),
#  (308, 'Benjamin', ' Reading the commandment Animals shall never drink alcoholto excess. ', 0.0, 1.0, 0.0, 0.0),
#  (309, 'Boxer', ' Oh dear, but Napoleon is always right ', 0.0, 0.741, 0.259, 0.2714),
#  (310, 'Benjamin', ' Why do you say that Boxer ', 0.0, 1.0, 0.0, 0.0),
#  (311, 'Boxer', ' Napoleon is our leader. We voted for him. ', 0.0, 1.0, 0.0, 0.0),
#  (312, 'Benjamin', ' We voted for a fair and honest leader for our revolution. He gets out the election promises leafet from the frst scene Listen, this is what Napoleon ... (74 characters truncated) ... sten to everyone. I promise to be fair. I promise to treat everyone equally. I promise to be honest. He has broken every one of his promises, Boxer. ', 0.038, 0.624, 0.338, 0.9661),
#  (313, 'Boxer', ' Yes, but it was so long ago. Everything is diferent now, everything has changed. ', 0.0, 0.875, 0.125, 0.2144),
#  (314, 'Benjamin', ' However much things change they always stay the same. ', 0.0, 1.0, 0.0, 0.0),
#  (315, 'Boxer', ' I will work harder. escapadetheatre.es Animal Farm EscapadeTheatre ', 0.0, 1.0, 0.0, 0.0),
#  (316, 'Benjamin', ' We cant go on like this Boxer. We will die ', 0.285, 0.545, 0.17, -0.4003),
#  (317, 'Boxer', ' Die Maybe life would be easier in heaven. ', 0.26, 0.333, 0.407, 0.296),
#  (318, 'Benjamin', ' Do you really believe in heaven, Boxer ', 0.0, 0.627, 0.373, 0.552),
#  (319, 'Boxer', ' Oh yes, animal heaven. Up there, in the clouds, theres a mountain, Sugar Candy Mountain, where we poor animals go when we die. He sings. On Sugar Ca ... (603 characters truncated) ... jah, hallelujah, the sugar candy choir Hallelujah, hallelujah, so fear no more the knackers yard Hallelujah, hallelujah, the sugar candy choir Scene ', 0.145, 0.553, 0.302, 0.9903),
#  (321, 'Napoleon', ' Shut up Be quiet you stupid animals. Whats all this noise on my farm ', 0.221, 0.779, 0.0, -0.5707),
#  (322, 'Squealer', ' From now on singing is prohibited. The revolution is complete and the only song you can sing is the new hymn, which I have written myself, for our great President Napoleon. ', 0.0, 0.876, 0.124, 0.6249),
#  (323, 'Benjamin', ' President ', 0.0, 1.0, 0.0, 0.0),
#  (324, 'Napoleon', ' Enters in full regalia Yes, thank you, thank you. I have been voted President. ', 0.0, 0.565, 0.435, 0.7717),
#  (325, 'Boxer', ' Voted by whom ', 0.0, 1.0, 0.0, 0.0),
#  (326, 'Napoleon', ' By me, myself and I. An absolute majority. I am President and Animal Farm is now a Republic. Sing the new hymn Squealer. ', 0.0, 1.0, 0.0, 0.0),
#  (327, 'Squealer', ' He sings. Napo-Napo-Napoleon-Napo-Napo-Napoleon-Napoleoooon escapadetheatre.es Animal Farm EscapadeTheatre ', 0.0, 1.0, 0.0, 0.0),
#  (328, 'Benjamin', ' Why do you say the revolution is complete Where is the three day week Where is the food and the riches Are we all free, rich and equal Where is our animal revolution ', 0.0, 0.727, 0.273, 0.9054),
#  (329, 'Napoleon', ' Show them the fgures, Squealer ', 0.0, 1.0, 0.0, 0.0),
#  (330, 'Squealer', ' Taking out the graphs Yes, we are much better of than with Jones. Look, productivity is up 35%, creativity is up by 22%, longevity is up by 50%, and therefore you are 100% more free, rich and equal During this Napoleon has gone over to the board and changed the commandments ', 0.0, 0.739, 0.261, 0.9456),
#  (331, 'Boxer', ' Its not true For once I protest. You pigs have gone far enough. What about the seven commandments What about All animals are equal ', 0.192, 0.808, 0.0, -0.6103),
#  (332, 'Squealer', ' Theres only one commandment now. Look. ', 0.0, 1.0, 0.0, 0.0),
#  (333, 'Napoleon', ' Reading All animals are equal, but some are more equal than others. ', 0.0, 1.0, 0.0, 0.0),
#  (334, 'Narrator', ' Just at that moment Pilkington came to congratulate Napoleon on his success. ', 0.0, 0.592, 0.408, 0.7845),
#  (335, 'Pilkington', ' Hello, hello. Mr. Napoleon. Congratulations You have the most proftable farm in England. Whats your secret ', 0.0, 0.782, 0.218, 0.636),
#  (336, 'Napoleon', ' Simple. More proft for fewer people. More power in fewer hands. More control of beast and human. Use every piece of land. ', 0.0, 1.0, 0.0, 0.0),
#  (337, 'Pilkington', ' Excellent Dear boy, excellent Congratulations Ladies and gentleman, I propose a toast, a toast to Animal Farm. ', 0.0, 0.404, 0.596, 0.9411),
#  (338, 'Napoleon', ' No, not to Animal Farm, a more appropriate name is Manor Farm. Squealer changes the sign ', 0.136, 0.864, 0.0, -0.296),
#  (339, 'Pilkington', ' Excellent To Manor Farm. ', 0.0, 0.429, 0.571, 0.6114),
#  (341, 'Narrator', ' The animals looked from pig to man and from man to pig again. But already it was impossible to tell which was which', 0.0, 1.0, 0.0, 0.0)]

# %%
pd.read_sql_query("""
SELECT name,compound FROM Anisql
group by name
order by compound desc;
""", engine)
# Out:
#           name  compound
# 0   Pilkington    0.5719
# 1      Animals    0.5080
# 2     Napoleon    0.0000
# 3         Cows    0.0000
# 4         Hens    0.0000
# 5     Squealer    0.0000
# 6     Benjamin    0.0000
# 7         Pigs    0.0000
# 8         PEPE    0.0000
# 9        Boxer   -0.4767
# 10    Narrator   -0.7960
